# %%
import pandas as pd
import numpy as np
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="48b726d47968467c95fdac23818963ee")>

# %%
driver.maximize_window()

# %%
url='https://www.olx.com/'
driver.get(url)

# %%
srch_job=driver.find_element(By.XPATH,"/html/body/div/div/header/div/div/div[2]/div/div/div[2]/div/form/fieldset/div/input")
srch_job.send_keys("used cars")

# %%
button=driver.find_element(By.XPATH,"/html/body/div/div/header/div/div/div[2]/div/div/div[3]")
button.click()

# %%
clk=driver.find_element(By.XPATH,"/html/body/div[1]/div/header/div/div/div[2]/div/div/div[3]")
clk.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in name_tag:
    names.append(i.text)
names
# Out:
# ['Hyundai Venue',
#  'Hyundai i20',
#  'Skoda Rapid',
#  'Chevrolet Beat',
#  'Renault KWID',
#  'Porsche 718',
#  'Hyundai i20 Active',
#  'Honda City',
#  'Hyundai i10',
#  'BMW 3 Series',
#  'Hyundai i20',
#  'Land Rover Discovery Sport',
#  'Maruti Suzuki Alto-800',
#  'Renault KWID',
#  'Tata Tigor EV',
#  'Mahindra Bolero',
#  'Audi A4',
#  'Toyota Etios',
#  'Maruti Suzuki Eeco',
#  'Hyundai Santro Xing',
#  'Maruti Suzuki Swift-Dzire',
#  'Skoda Octavia',
#  'Maruti Suzuki Alto-K10',
#  'Ford Figo Aspire',
#  'Ford Figo',
#  'Maruti Suzuki Swift-Dzire',
#  'Mahindra Bolero',
#  'Porsche 718',
#  'Tata Indica V2',
#  'Ashok Leyland Stile',
#  'Honda City',
#  'Hyundai Creta',
#  'Maruti Suzuki Vitara-Brezza',
#  'Tata Tigor',
#  'Hyundai Creta',
#  'Maruti Suzuki 800',
#  'Renault Triber',
#  'Toyota Fortuner',
#  'Maruti Suzuki Ertiga',
#  'Maruti Suzuki Zen-Estilo']

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//div[@class="_3VRSm"]')
for i in area_tag:
    area.append(i.text)
area
# Out:
# ['Indira Nagar\nJan 22',
#  'Kedari Nagar\nJan 21',
#  'Banjara Hills\n4 days ago',
#  'Dhanurjayapur\nToday',
#  'Banganga Colony\nToday',
#  'Ashok Vihar\nToday',
#  'Ring Road\nToday',
#  'Bandra West\nToday',
#  'Kot Baba Deep Singh\nToday',
#  'Vaishali Nagar\nToday',
#  'Bandra West\nToday',
#  'HRBR Layout\nToday',
#  'Shahdara\nToday',
#  'Banganga Colony\nToday',
#  'Airoli\nToday',
#  'Krishnapur\nToday',
#  'Andheri West\nToday',
#  'Batampur\nToday',
#  'Mylapore\nJan 30',
#  'Attapur Ring Road\nNov 22',
#  'City Center\n3 days ago',
#  'Vanagaram Kannada Puram\nToday',
#  'Baba Lalu Ji Holy Place\nToday',
#  'Pallickathod\nToday',
#  'Podanur\nToday',
#  'Nehru Bazar\nToday',
#  'Seth Gop Jeevan Lal Gopaldas Anand Nagar',
#  'Vikaspuri\nToday',
#  'Gandhari\nToday',
#  'Thippapuram\nToday',
#  'Kanjirapally\nToday',
#  'Shamshabad\nToday',
#  'Sector 118\nToday',
#  'South Bopal\nToday',
#  'Uttar Panchanan Gram\nToday',
#  'Sorathur\nToday',
#  'Marri Palem\nToday',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//div[@class="_21gnE"]')
for i in year_tag:
    year.append(i.text[0:4])
year
# Out:
# ['2020',
#  '2013',
#  '2013',
#  '2016',
#  '2018',
#  '2017',
#  '2015',
#  '2021',
#  '2013',
#  '2018',
#  '2017',
#  '2018',
#  '2014',
#  '2018',
#  '2019',
#  '2015',
#  '2012',
#  '2012',
#  '2016',
#  '2007',
#  '2017',
#  '2006',
#  '2011',
#  '2017',
#  '2011',
#  '2019',
#  '2014',
#  '2017',
#  '2007',
#  '2007',
#  '2014',
#  '2016',
#  '2020',
#  '2021',
#  '2017',
#  '2023',
#  '2020',
#  '2016',
#  '2013',
#  '2012']

# %%
kms=[]
kms_tag=driver.find_elements(By.XPATH,'//div[@class="_21gnE"]')
for i in kms_tag:
    kms.append(i.text[6:])
kms
# Out:
# [' 17,206 km',
#  ' 30,000 km',
#  ' 92,000 km',
#  ' 180,000 km',
#  ' 30,000 km',
#  ' 28,000 km',
#  ' 69,000 km',
#  ' 40,000 km',
#  ' 57,000 km',
#  ' 68,000 km',
#  ' 12,000 km',
#  ' 107,000 km',
#  ' 26,000 km',
#  ' 22,000 km',
#  ' 10,000 km',
#  ' 80,000 km',
#  ' 50,000 km',
#  ' 90,000 km',
#  ' 30,000 km',
#  ' 148,000 km',
#  ' 77,000 km',
#  ' 120,000 km',
#  ' 120,000 km',
#  ' 161,000 km',
#  ' 91,000 km',
#  ' 31,000 km',
#  ' 15 km',
#  ' 28,000 km',
#  ' 250,000 km',
#  '',
#  ' 102,000 km',
#  ' 134,000 km',
#  ' 50,000 km',
#  ' 6,200 km',
#  ' 22,703 km',
#  ' 10 km',
#  ' 50,000 km',
#  ' 87,000 km',
#  ' 88,000 km',
#  ' 58,730 km']

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//span[@class="_1zgtX"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹ 10,65,000',
#  '₹ 3,75,000',
#  '₹ 3,80,000',
#  '₹ 1,70,000',
#  '₹ 2,50,000',
#  '₹ 85,75,000',
#  '₹ 5,75,000',
#  '₹ 12,50,000',
#  '₹ 2,67,000',
#  '₹ 27,50,000',
#  '₹ 5,85,000',
#  '₹ 40,00,000',
#  '₹ 2,55,000',
#  '₹ 25,000',
#  '₹ 6,75,000',
#  '₹ 4,18,000',
#  '₹ 10,75,000',
#  '₹ 4,00,000',
#  '₹ 4,10,000',
#  '₹ 2,00,000',
#  '₹ 5,85,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 4,20,000',
#  '₹ 2,05,000',
#  '₹ 6,40,000',
#  '₹ 5,00,000',
#  '₹ 85,75,000',
#  '₹ 1,20,000',
#  '₹ 6,30,000',
#  '₹ 5,39,000',
#  '₹ 9,00,000',
#  '₹ 9,25,000',
#  '₹ 7,25,000',
#  '₹ 7,49,000',
#  '₹ 50,000',
#  '₹ 6,95,000',
#  '₹ 17,75,000',
#  '₹ 5,15,000',
#  '₹ 2,50,000']

# %%
cars=pd.DataFrame()
cars['Names']=names
cars['Area']=area
cars['Year of purchase']=year
cars['Kms run']=kms
cars['Price']=price
cars
# Out:
#                           Names                                      Area  \
# 0                 Hyundai Venue                      Indira Nagar\nJan 22
# 1                   Hyundai i20                      Kedari Nagar\nJan 21
# 2                   Skoda Rapid                 Banjara Hills\n4 days ago
# 3                Chevrolet Beat                      Dhanurjayapur\nToday
# 4                  Renault KWID                    Banganga Colony\nToday
# 5                   Porsche 718                        Ashok Vihar\nToday
# 6            Hyundai i20 Active                          Ring Road\nToday
# 7                    Honda City                        Bandra West\nToday
# 8                   Hyundai i10                Kot Baba Deep Singh\nToday
# 9                  BMW 3 Series                     Vaishali Nagar\nToday
# 10                  Hyundai i20                        Bandra West\nToday
# 11   Land Rover Discovery Sport                        HRBR Layout\nToday
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c77f15fcff59c2000b06ef92005fc6d6")>

# %%
driver.maximize_window()

# %%
url='https://www.cardekho.com/'
driver.get(url)

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h3[@class="title"]')
for i in name_tag:
    names.append(i.text[4:])
names
# Out:
# [' Renault Duster Petrol RxL',
#  ' Ford Ecosport 1.5 DV5 MT Titanium',
#  ' Volkswagen Vento Petrol Highline',
#  ' Hyundai i20 1.2 Asta',
#  ' Maruti Swift Dzire LXI Option',
#  ' Ford Ecosport 1.5 DV5 MT Titanium',
#  ' Maruti Swift Dzire LXI Option',
#  ' Honda City 1.5 E MT',
#  ' Hyundai Grand i10 1.2 Kappa Sportz BSIV',
#  ' Hyundai i10 Magna 1.1L',
#  ' Ford Figo Petrol Titanium',
#  ' Hyundai Grand i10 AT Asta',
#  ' Honda Brio S MT',
#  ' Hyundai i10 Era',
#  ' Honda Accord 2.4 A/T',
#  ' Hyundai EON Era Plus',
#  ' Hyundai EON Era Plus',
#  ' Hyundai i20 1.4 Sportz',
#  ' Maruti Swift VXI',
#  ' Ford Ecosport 1.5 Diesel Trend Plus BSIV',
#  ' Hyundai EON Magna Plus',
#  ' Hyundai Santro Sportz Executive CNG',
#  ' Maruti Alto 800 LXI Optional',
#  ' Maruti Celerio ZXI AMT BSIV',
#  ' Maruti Wagon R LXI CNG Optional',
#  ' Maruti Swift Dzire VXI 1.2 BS IV',
#  ' Mahindra Scorpio SLE BSIV',
#  ' Mahindra KUV 100 NXT G80 K2 Plus 6 Str',
#  ' Renault KWID RXT',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h3[@class="title"]')
for i in year_tag:
    year.append(i.text[0:5])
year
# Out:
# ['2013 ',
#  '2014 ',
#  '2012 ',
#  '2011 ',
#  '2013 ',
#  '2015 ',
#  '2014 ',
#  '2008 ',
#  '2018 ',
#  '2015 ',
#  '2011 ',
#  '2014 ',
#  '2012 ',
#  '2013 ',
#  '2010 ',
#  '2015 ',
#  '2016 ',
#  '2017 ',
#  '2013 ',
#  '2015 ',
#  '2016 ',
#  '2019 ',
#  '2018 ',
#  '2018 ',
#  '2018 ',
#  '2015 ',
#  '2013 ',
#  '2017 ',
#  '2016 ',
#  '2017 ',
#  '2010 ',
#  '2015 ',
#  '2016 ',
#  '2018 ',
#  '2014 ',
#  '2013 ',
#  '2011 ',
#  '2015 ',
#  '2013 ',
#  '2017 ',
#  '2012 ',
#  '2015 ',
#  '2015 ',
#  '2011 ',
#  '2010 ',
#  '2014 ',
#  '2018 ',
#  '2018 ',
#  '2014 ',
#  '2011 ',
#  '2016 ',
#  '2011 ',
#  '2010 ',
#  '2012 ',
#  '2008 ',
#  '2015 ',
#  '2009 ',
#  '2014 ',
#  '2018 ',
#  '2013 ']

# %%
kms_run=[]
km_tag=driver.find_elements(By.XPATH,'//div[@class="dotsDetails"]')
for i in km_tag:
    kms_run.append(i.text[0:13])
kms_run
# Out:
# ['59,738 kms • ',
#  '71,000 kms • ',
#  '84,000 kms • ',
#  '54,980 kms • ',
#  '42,000 kms • ',
#  '52,000 kms • ',
#  '55,000 kms • ',
#  '60,000 kms • ',
#  '47,133 kms • ',
#  '58,390 kms • ',
#  '60,000 kms • ',
#  '65,000 kms • ',
#  '60,000 kms • ',
#  '52,000 kms • ',
#  '93,000 kms • ',
#  '57,454 kms • ',
#  '39,854 kms • ',
#  '88,614 kms • ',
#  '63,000 kms • ',
#  '62,000 kms • ',
#  '1,11,733 kms ',
#  '49,000 kms • ',
#  '48,000 kms • ',
#  '60,000 kms • ',
#  '32,000 kms • ',
#  '69,000 kms • ',
#  '82,000 kms • ',
#  '63,000 kms • ',
#  '30,333 kms • ',
#  '28,422 kms • ',
#  '30,571 kms • ',
#  '74,477 kms • ',
#  '71,161 kms • ',
#  '36,453 kms • ',
#  '52,000 kms • ',
#  '1,14,415 kms ',
#  '22,158 kms • ',
#  '15,000 kms • ',
#  '78,000 kms • ',
#  '68,000 kms • ',
#  '86,000 kms • ',
#  '41,749 kms • ',
#  '71,653 kms • ',
#  '36,273 kms • ',
#  '96,902 kms • ',
#  '1,24,234 kms ',
#  '9,957 kms • P',
#  '95,000 kms • ',
#  '83,208 kms • ',
#  '79,307 kms • ',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//div[@class="dotsDetails"]')
for i in type_tag:
    types.append(i.text[13:])
types
# Out:
# ['Petrol • Manual',
#  'Diesel • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Diesel • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Automatic',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Automatic',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Diesel • Manual',
#  'Petrol • Manual',
#  'Diesel • Manual',
#  '• Petrol • Manual',
#  'CNG • Manual',
#  'Petrol • Manual',
#  'Petrol • Automatic',
#  'CNG • Manual',
#  'Petrol • Manual',
#  'Diesel • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'CNG • Manual',
#  'Diesel • Manual',
#  'Petrol • Automatic',
#  'Petrol • Automatic',
#  'Petrol • Manual',
#  '• Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
#  'Diesel • Manual',
#  'Diesel • Manual',
#  'Petrol • Manual',
#  'Petrol • Manual',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="Price hover"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹ 3.07 Lakh',
#  '₹ 4.10 Lakh',
#  '₹ 2.35 Lakh',
#  '₹ 2.15 Lakh',
#  '₹ 3.70 Lakh',
#  '₹ 4.61 Lakh',
#  '₹ 3.95 Lakh',
#  '₹ 1.20 Lakh',
#  '₹ 4.35 Lakh',
#  '₹ 3.15 Lakh',
#  '₹ 1.10 Lakh',
#  '₹ 4.65 Lakh',
#  '₹ 2.35 Lakh',
#  '₹ 2.80 Lakh',
#  '₹ 4.35 Lakh',
#  '₹ 1.99 Lakh',
#  '₹ 2.25 Lakh',
#  '₹ 4.48 Lakh',
#  '₹ 3.75 Lakh',
#  '₹ 3.95 Lakh',
#  '₹ 1.79 Lakh',
#  '₹ 4.85 Lakh',
#  '₹ 2.95 Lakh',
#  '₹ 4.70 Lakh',
#  '₹ 3.95 Lakh',
#  '₹ 4.40 Lakh',
#  '₹ 3.80 Lakh',
#  '₹ 4 Lakh',
#  '₹ 1.90 Lakh',
#  '₹ 3.75 Lakh',
#  '₹ 2 Lakh',
#  '₹ 3.40 Lakh',
#  '₹ 4.50 Lakh',
#  '₹ 4.55 Lakh',
#  '₹ 2.40 Lakh',
#  '₹ 2.50 Lakh',
#  '₹ 1.50 Lakh',
#  '₹ 2.27 Lakh',
#  '₹ 2.25 Lakh',
#  '₹ 4.25 Lakh',
#  '₹ 4.65 Lakh',
#  '₹ 4.97 Lakh',
#  '₹ 4 Lakh',
#  '₹ 1.20 Lakh',
#  '₹ 1.30 Lakh',
#  '₹ 3 Lakh',
#  '₹ 4.70 Lakh',
#  '₹ 3.55 Lakh',
#  '₹ 3.10 Lakh',
#  '₹ 1.70 Lakh',
#  '₹ 4.10 Lakh',
#  '₹ 3.50 Lakh',
#  '₹ 1.20 Lakh',
#  '₹ 2.50 Lakh',
#  '₹ 2 Lakh',
#  '₹ 3.40 Lakh',
# ...

# %%
cars_1=pd.DataFrame()
cars_1['Names']=names
cars_1['Types']=types
cars_1['Year of purchase']=year
cars_1['Kms run']=kms_run
cars_1['Price']=price
cars_1
# Out:
#                                         Names               Types  \
# 0                   Renault Duster Petrol RxL     Petrol • Manual
# 1           Ford Ecosport 1.5 DV5 MT Titanium     Diesel • Manual
# 2            Volkswagen Vento Petrol Highline     Petrol • Manual
# 3                        Hyundai i20 1.2 Asta     Petrol • Manual
# 4               Maruti Swift Dzire LXI Option     Petrol • Manual
# 5           Ford Ecosport 1.5 DV5 MT Titanium     Diesel • Manual
# 6               Maruti Swift Dzire LXI Option     Petrol • Manual
# 7                         Honda City 1.5 E MT     Petrol • Manual
# 8     Hyundai Grand i10 1.2 Kappa Sportz BSIV     Petrol • Manual
# 9                      Hyundai i10 Magna 1.1L     Petrol • Manual
# 10                  Ford Figo Petrol Titanium     Petrol • Manual
# 11                  Hyundai Grand i10 AT Asta  Petrol • Automatic
# 12                            Honda Brio S MT     Petrol • Manual
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c7c2a59d6cf6042c445b8efb34a0d059")>

# %%
driver.maximize_window()

# %%
url='https://www.Cars24.com/'
driver.get(url)

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section/div/div/div[2]/button')
button.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag:
    names.append(i.text[4:])
names
# Out:
# [' MERCEDES BENZ E CLASS',
#  ' Volkswagen Polo',
#  ' Renault KWID',
#  ' Mahindra KUV 100 NXT',
#  ' Hyundai i20',
#  ' Ford Ecosport',
#  ' Maruti ERTIGA',
#  ' Maruti SWIFT DZIRE',
#  ' Ford Ecosport',
#  ' Honda City',
#  ' Volkswagen Polo',
#  ' Maruti Wagon R 1.0',
#  ' Maruti Wagon R 1.0',
#  ' Maruti WAGON R 1.0',
#  ' Maruti Celerio',
#  ' Honda Amaze',
#  ' Skoda Superb',
#  ' Maruti Wagon R 1.0',
#  ' Volkswagen Polo',
#  ' MARUTI ERTIGA']

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag:
    year.append(i.text[0:4])
year
# Out:
# ['2011',
#  '2013',
#  '2016',
#  '2018',
#  '2010',
#  '2014',
#  '2017',
#  '2012',
#  '2014',
#  '2016',
#  '2012',
#  '2013',
#  '2013',
#  '2014',
#  '2015',
#  '2013',
#  '2015',
#  '2015',
#  '2018',
#  '2017']

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_1hOnS"]')
for i in type_tag:
    types.append(i.text)
types
# Out:
# ['E 250 CDI ELEGANCEAutomatic',
#  'COMFORTLINE 1.2L PETROLManual',
#  'RXTManual',
#  'K8 D 6 SEATERManual',
#  'ASTA 1.2Manual',
#  '1.5 TITANIUMTDCI OPTManual',
#  'VXI ATAutomatic',
#  'VXIManual',
#  '1.5 TITANIUMTDCI OPTManual',
#  'VX CVT PETROLAutomatic',
#  'HIGHLINE1.2L PETROLManual',
#  'LXI CNGManual',
#  'LXIManual',
#  'LXI CNGManual',
#  'VXI AMTAutomatic',
#  '1.2 SMT I VTECManual',
#  'ELEGANCE 1.8 TSI ATAutomatic',
#  'LXI CNGManual',
#  'HIGH LINE PLUS 1.0Manual',
#  'VXI CNGManual']

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag:
    kms.append(i.text[0:9])
kms
# Out:
# ['78,206 KM',
#  '17,436 KM',
#  '47,587 KM',
#  '20,768 KM',
#  '30,864 KM',
#  '73,528 KM',
#  '54,033 KM',
#  '23,969 KM',
#  '94,040 KM',
#  '84,204 KM',
#  '61,553 KM',
#  '98,747 KM',
#  '53,256 KM',
#  '28,763 KM',
#  '58,669 KM',
#  '26,270 KM',
#  '81,945 KM',
#  '79,706 KM',
#  '32,263 KM',
#  '78,587 KM']

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag[0:20]:
    price.append(i.text)
price
# Out:
# ['₹9,36,000\n₹10,64,000',
#  '₹2,81,000',
#  '₹2,57,000',
#  '₹5,70,000\n₹6,34,000',
#  '₹2,49,000',
#  '₹5,90,000\n₹6,47,000',
#  '₹6,78,000',
#  '₹3,84,000\n₹3,92,000',
#  '₹5,72,000\n₹6,00,000',
#  '₹7,63,000\n₹8,12,000',
#  '₹3,25,000\n₹3,30,000',
#  '₹3,47,000',
#  '₹2,90,000',
#  '₹3,30,900',
#  '₹3,81,000\n₹4,16,000',
#  '₹3,67,000\n₹4,43,000',
#  '₹7,85,000\n₹8,65,000',
#  '₹4,20,000',
#  '₹5,73,000\n₹6,69,000',
#  '₹7,75,000']

# %%
cars_2=pd.DataFrame()
cars_2['Names']=names
cars_2['Types']=types
cars_2['Year of purchase']=year
cars_2['Kms run']=kms
cars_2['Price']=price
cars_2
# Out:
#                      Names                          Types Year of purchase  \
# 0    MERCEDES BENZ E CLASS    E 250 CDI ELEGANCEAutomatic             2011
# 1          Volkswagen Polo  COMFORTLINE 1.2L PETROLManual             2013
# 2             Renault KWID                      RXTManual             2016
# 3     Mahindra KUV 100 NXT            K8 D 6 SEATERManual             2018
# 4              Hyundai i20                 ASTA 1.2Manual             2010
# 5            Ford Ecosport     1.5 TITANIUMTDCI OPTManual             2014
# 6            Maruti ERTIGA                VXI ATAutomatic             2017
# 7       Maruti SWIFT DZIRE                      VXIManual             2012
# 8            Ford Ecosport     1.5 TITANIUMTDCI OPTManual             2014
# 9               Honda City         VX CVT PETROLAutomatic             2016
# 10         Volkswagen Polo      HIGHLINE1.2L PETROLManual             2012
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e1868eea0cec7e8a578eb2ae973b7cc6")>

# %%
driver.maximize_window()

# %%
url='https://www.spinny.com/'
driver.get(url)

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in name_tag:
    names.append(i.text[4:])
names
# Out:
# [' Mahindra XUV 300 W8 AMT (O) Diesel',
#  ' Honda WR-V i-DTEC VX',
#  ' Honda Brio S(O)MT',
#  ' Renault Duster 85 PS RxE 4X2 MT',
#  ' Hyundai i10 Sportz Petrol',
#  ' Hyundai Santro Xing GLS',
#  ' Maruti Suzuki Ciaz Alpha AT Petrol',
#  ' Maruti Suzuki Eeco AC 5 STR',
#  ' Mahindra Bolero B6',
#  ' Tata Harrier XZ',
#  ' Nissan Sunny XL',
#  ' Mahindra Marazzo M2',
#  ' Tata Altroz XZ 1.2',
#  ' Mahindra Thar LX 4 STR Hard Top Petrol AT',
#  ' Honda Amaze 1.2 VX CVT i-VTEC',
#  ' Tata Tiago XZA+ AMT',
#  ' Renault Kwid RXT 1.0 SCE Special',
#  ' Honda City V',
#  ' Maruti Suzuki Swift LDi',
#  ' Toyota Innova Crysta 2.7 VX 7 STR',
#  ' Hyundai Grand i10 Nios Sportz 1.2 Kappa VTVT CNG',
#  ' Ford EcoSport Titanium 1.5L Ti-VCT',
#  ' Hyundai Grand i10 Nios Sportz 1.2 Kappa VTVT',
#  ' Toyota Innova Crysta 2.4 GX AT 7 STR',
#  ' Hyundai Creta SX Diesel',
#  ' Maruti Suzuki Ritz Vdi',
#  ' Maruti Suzuki Baleno Alpha AT Petrol',
#  ' Mahindra Bolero B6 (O)',
# ...

# %%
len(names)
# Out:
# 60

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in type_tag:
    types.append(i.text[7:])
types
# Out:
# ['m\nDiesel\nAutomatic',
#  'm\nDiesel\nManual',
#  'm\nPetrol',
#  'm\nDiesel\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nAutomatic',
#  '\nPetrol\nManual',
#  '\nDiesel',
#  'm\nDiesel\nManual',
#  'm\nPetrol\nManual',
#  'm\nDiesel',
#  'm\nPetrol\nManual',
#  'etrol\nAutomatic',
#  '\nPetrol',
#  '\nPetrol\nAutomatic',
#  'Petrol\nManual',
#  'm\nPetrol',
#  'm\nDiesel\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol+cng',
#  'm\nPetrol\nManual',
#  '\nPetrol\nManual',
#  '\nDiesel',
#  'm\nDiesel\nManual',
#  'Diesel\nManual',
#  'etrol',
#  'm\nDiesel\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nDiesel\nManual',
#  'm\nPetrol+cng\nManual',
#  'm\nPetrol',
#  'm\nDiesel\nManual',
#  'Petrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nAutomatic',
#  'm\nPetrol',
#  'm\nDiesel\nAutomatic',
#  'm\nPetrol\nManual',
#  '\nPetrol',
#  'm\nPetrol\nManual',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in km_tag:
    kms.append(i.text[0:8])
kms
# Out:
# ['57.5K km',
#  '14.7K km',
#  '82.5K km',
#  '84.4K km',
#  '46.7K km',
#  '33.8K km',
#  '44.5K km',
#  '7.9K km\n',
#  '8.9K km\n',
#  '56.6K km',
#  '48.5K km',
#  '57.6K km',
#  '26.5K km',
#  '8K km\nPe',
#  '4.4K km\n',
#  '9.5K km\n',
#  '43K km\nP',
#  '51.8K km',
#  '26.6K km',
#  '14.3K km',
#  '28.1K km',
#  '44.7K km',
#  '9.3K km\n',
#  '8.7K km\n',
#  '30.9K km',
#  '62K km\nD',
#  '4K km\nPe',
#  '30.9K km',
#  '22.7K km',
#  '56.9K km',
#  '78.4K km',
#  '14.7K km',
#  '29.9K km',
#  '52.3K km',
#  '37K km\nP',
#  '44.3K km',
#  '36.3K km',
#  '42.5K km',
#  '60.3K km',
#  '42.5K km',
#  '92.9K km',
#  '26.3K km',
#  '39.6K km',
#  '60.1K km',
#  '3.8K km\n',
#  '65.7K km',
#  '46.6K km',
#  '46.5K km',
#  '89.5K km',
#  '75.9K km',
#  '39.4K km',
#  '92.8K km',
#  '15.1K km',
#  '35.5K km',
#  '46.5K km',
#  '39.6K km',
#  '47.2K km',
#  '34.4K km',
#  '24.9K km',
#  '33.8K km']

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in year_tag:
    year.append(i.text[0:4])
year
# Out:
# ['2019',
#  '2017',
#  '2012',
#  '2018',
#  '2016',
#  '2014',
#  '2018',
#  '2020',
#  '2022',
#  '2019',
#  '2013',
#  '2019',
#  '2021',
#  '2022',
#  '2020',
#  '2022',
#  '2017',
#  '2016',
#  '2014',
#  '2016',
#  '2020',
#  '2017',
#  '2021',
#  '2021',
#  '2020',
#  '2014',
#  '2022',
#  '2020',
#  '2017',
#  '2016',
#  '2017',
#  '2019',
#  '2019',
#  '2019',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2015',
#  '2014',
#  '2018',
#  '2019',
#  '2017',
#  '2017',
#  '2021',
#  '2012',
#  '2019',
#  '2017',
#  '2013',
#  '2013',
#  '2016',
#  '2016',
#  '2019',
#  '2018',
#  '2020',
#  '2013',
#  '2018',
#  '2017',
#  '2019',
#  '2018']

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//li[@class="TestDriveAvailability__changeLocationColor"]')
for i in area_tag:
    area.append(i.text)
area
# Out:
# ['Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Ghaziabad (Sahibabad)',
#  'Spinny Hub, NSP, Delhi',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Grand Mall, Gurgaon',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Taj Vivanta, Dwarka, Delhi',
#  'Spinny Hub, Trillium Avenue, Gurgaon',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
#  'Spinny Hub, Gaur City, Noida',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//li[@class="styles__price"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹10.44 Lakh',
#  '₹6.97 Lakh',
#  '₹2.56 Lakh',
#  '₹5.55 Lakh',
#  '₹3.74 Lakh',
#  '₹2.91 Lakh',
#  '₹9.33 Lakh',
#  '₹4.20 Lakh',
#  '₹9.76 Lakh',
#  '₹14.29 Lakh',
#  '₹3.08 Lakh',
#  '₹7.99 Lakh',
#  '₹7.60 Lakh',
#  '₹16.22 Lakh',
#  '₹8.26 Lakh',
#  '₹7.01 Lakh',
#  '₹3.67 Lakh',
#  '₹6.66 Lakh',
#  '₹3.49 Lakh',
#  '₹12.79 Lakh',
#  '₹7.15 Lakh',
#  '₹6.53 Lakh',
#  '₹6.42 Lakh',
#  '₹21.76 Lakh',
#  '₹15.33 Lakh',
#  '₹3.22 Lakh',
#  '₹9.64 Lakh',
#  '₹8.39 Lakh',
#  '₹6.32 Lakh',
#  '₹3.79 Lakh',
#  '₹6.75 Lakh',
#  '₹6.62 Lakh',
#  '₹4.91 Lakh',
#  '₹13.91 Lakh',
#  '₹9.86 Lakh',
#  '₹12.11 Lakh',
#  '₹7.33 Lakh',
#  '₹8.54 Lakh',
#  '₹4.35 Lakh',
#  '₹4.36 Lakh',
#  '₹7.54 Lakh',
#  '₹14.27 Lakh',
#  '₹10.28 Lakh',
#  '₹7.22 Lakh',
#  '₹4.51 Lakh',
#  '₹3.59 Lakh',
#  '₹14.84 Lakh',
#  '₹6.62 Lakh',
#  '₹5.16 Lakh',
#  '₹4.84 Lakh',
#  '₹7.48 Lakh',
#  '₹8.49 Lakh',
#  '₹4.36 Lakh',
#  '₹8.15 Lakh',
#  '₹11.78 Lakh',
#  '₹3.68 Lakh',
#  '₹12 Lakh',
#  '₹5.23 Lakh',
# ...

# %%
cars_3=pd.DataFrame()
cars_3['Names']=names
cars_3['Types']=types
cars_3['Year of purchase']=year
cars_3['Kms run']=kms
cars_3['Price']=price
cars_3['Area']=area
cars_3
# Out:
#                                                 Names                  Types  \
# 0                  Mahindra XUV 300 W8 AMT (O) Diesel   m\nDiesel\nAutomatic
# 1                                Honda WR-V i-DTEC VX      m\nDiesel\nManual
# 2                                   Honda Brio S(O)MT              m\nPetrol
# 3                     Renault Duster 85 PS RxE 4X2 MT      m\nDiesel\nManual
# 4                           Hyundai i10 Sportz Petrol      m\nPetrol\nManual
# 5                             Hyundai Santro Xing GLS              m\nPetrol
# 6                  Maruti Suzuki Ciaz Alpha AT Petrol   m\nPetrol\nAutomatic
# 7                         Maruti Suzuki Eeco AC 5 STR       \nPetrol\nManual
# 8                                  Mahindra Bolero B6               \nDiesel
# 9                                     Tata Harrier XZ      m\nDiesel\nManual
# 10                                    Nissan Sunny XL      m\nPetrol\nManual
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5561d8629a9b45a119686141199a38e4")>

# %%
driver.maximize_window()

# %%
url='https://www.spinny.com/'
driver.get(url)

# %%
btn=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/div[3]/div[2]/div/div[2]/div/div[1]/div/div/div/button')
btn.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in name_tag:
    names.append(i.text[4:])
names
# Out:
# [' Mahindra Marazzo M8',
#  ' Hyundai Grand i10 Sportz 1.2 Kappa VTVT',
#  ' Hyundai Elite i20 Asta 1.2',
#  ' Tata Tiago Revotron XZ',
#  ' Honda WR-V i-DTEC VX',
#  ' Renault Kwid RXT 1.0 SCE Special (O)',
#  ' Maruti Suzuki New Ertiga VXI AT',
#  ' Hyundai Grand i10 Asta AT 1.2 Kappa VTVT',
#  ' Ford Figo Aspire Titanium 1.2 Ti-VCT',
#  ' Renault Kwid 1.0 RXT',
#  ' Honda WR-V i-VTEC VX',
#  ' Maruti Suzuki Swift VXI',
#  ' Hyundai i10 Sportz Petrol',
#  ' Maruti Suzuki Alto 800 VXI (O)',
#  ' Hyundai Venue SX 1.0 (O) Turbo',
#  ' Maruti Suzuki Baleno Alpha Petrol',
#  ' Hyundai Creta 1.6 SX OPT VTVT',
#  ' Hyundai Creta 1.6 SX Plus Petrol',
#  ' Hyundai Creta 1.6 SX Plus Petrol',
#  ' Hyundai Venue S 1.0 Turbo iMT',
#  ' Hyundai i10 Sportz 1.2 Petrol',
#  ' Hyundai i10 Magna 1.2 Petrol',
#  ' Hyundai Creta 1.6 SX Plus Petrol',
#  ' Hyundai Venue SX 1.0 Turbo iMT',
#  ' Hyundai Venue SX 1.0 (O) Turbo',
#  ' Ford Freestyle Titanium 1.2',
#  ' Hyundai Creta 1.6 SX Plus Petrol',
# ...

# %%
len(names)
# Out:
# 160

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in type_tag:
    types.append(i.text[7:])
types
# Out:
# ['m\nDiesel\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'Diesel\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nAutomatic',
#  'm\nPetrol\nAutomatic',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  '\nPetrol\nManual',
#  '\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'Petrol',
#  'm\nPetrol\nManual',
#  'Petrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  '\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  '\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'm\nDiesel',
#  'm\nDiesel\nManual',
#  'm\nDiesel\nManual',
#  'm\nDiesel',
#  'm\nDiesel\nManual',
#  'm\nDiesel\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'Petrol\nManual',
#  'm\nDiesel',
#  'm\nPetrol\nAutomatic',
#  'm\nDiesel\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
#  'm\nPetrol\nManual',
#  'm\nPetrol',
#  'm\nPetrol\nManual',
# ...

# %%
len(types)
# Out:
# 160

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in km_tag:
    kms.append(i.text[0:8])
kms
# Out:
# ['91.6K km',
#  '13.4K km',
#  '22.1K km',
#  '30.4K km',
#  '28K km\nD',
#  '10.1K km',
#  '41.2K km',
#  '23.2K km',
#  '55.6K km',
#  '53.8K km',
#  '4.6K km\n',
#  '5.9K km\n',
#  '55.3K km',
#  '23.7K km',
#  '26K km\nP',
#  '41.5K km',
#  '70K km\nP',
#  '62.8K km',
#  '40.2K km',
#  '9.3K km\n',
#  '74.7K km',
#  '70.6K km',
#  '71.2K km',
#  '14.7K km',
#  '49.1K km',
#  '43.3K km',
#  '57.2K km',
#  '9.7K km\n',
#  '12.7K km',
#  '51.7K km',
#  '32.6K km',
#  '49.3K km',
#  '36.6K km',
#  '30.2K km',
#  '87.1K km',
#  '30.2K km',
#  '30.1K km',
#  '17K km\nP',
#  '56.3K km',
#  '35.7K km',
#  '36.5K km',
#  '10.6K km',
#  '72.2K km',
#  '23.8K km',
#  '11.4K km',
#  '73.8K km',
#  '41.5K km',
#  '50K km\nD',
#  '8.7K km\n',
#  '41.3K km',
#  '47.2K km',
#  '39.7K km',
#  '11.8K km',
#  '62.5K km',
#  '41.5K km',
#  '28.7K km',
#  '99.1K km',
#  '13.8K km',
#  '29.7K km',
#  '17.6K km',
#  '11.2K km',
#  '92.7K km',
#  '52.2K km',
#  '58.7K km',
#  '56.1K km',
# ...

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//li[@class="TestDriveAvailability__changeLocationColor"]')
for i in area_tag:
    area.append(i.text)
area
# Out:
# ['Spinny Hub, Mantri Mall, Bangalore',
#  'Spinny Hub, Mantri Mall, Bangalore',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Hub, Mantri Mall, Bangalore',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Hub, Mantri Mall, Bangalore',
#  'Spinny Hub, Mantri Mall, Bangalore',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Hub, VR Mall, Bangalore',
#  'Spinny Hub, Bangalore Vega Mall',
#  'Spinny Park, Yelahanka, Bangalore',
#  'Spinny Park, Yelahanka, Bangalore',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in year_tag:
    year.append(i.text[0:5])
year
# Out:
# ['2018 ',
#  '2018 ',
#  '2015 ',
#  '2018 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2015 ',
#  '2016 ',
#  '2016 ',
#  '2022 ',
#  '2021 ',
#  '2014 ',
#  '2018 ',
#  '2020 ',
#  '2017 ',
#  '2018 ',
#  '2017 ',
#  '2016 ',
#  '2021 ',
#  '2011 ',
#  '2011 ',
#  '2016 ',
#  '2020 ',
#  '2020 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2020 ',
#  '2020 ',
#  '2020 ',
#  '2021 ',
#  '2020 ',
#  '2020 ',
#  '2015 ',
#  '2021 ',
#  '2016 ',
#  '2020 ',
#  '2017 ',
#  '2017 ',
#  '2020 ',
#  '2011 ',
#  '2012 ',
#  '2017 ',
#  '2021 ',
#  '2012 ',
#  '2015 ',
#  '2017 ',
#  '2020 ',
#  '2017 ',
#  '2013 ',
#  '2013 ',
#  '2021 ',
#  '2016 ',
#  '2018 ',
#  '2020 ',
#  '2015 ',
#  '2019 ',
#  '2020 ',
#  '2021 ',
#  '2020 ',
#  '2013 ',
#  '2016 ',
#  '2016 ',
#  '2014 ',
#  '2014 ',
#  '2017 ',
#  '2019 ',
#  '2017 ',
#  '2019 ',
#  '2019 ',
#  '2021 ',
#  '2015 ',
#  '2014 ',
#  '2018 ',
#  '2015 ',
#  '2013 ',
#  '2012 ',
#  '2020 ',
#  '2016 ',
#  '2016 ',
#  '2011 ',
#  '2020 ',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//li[@class="styles__price"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹10.24 Lakh',
#  '₹6.31 Lakh',
#  '₹6.63 Lakh',
#  '₹5.35 Lakh',
#  '₹7.91 Lakh',
#  '₹3.99 Lakh',
#  '₹9.87 Lakh',
#  '₹5.92 Lakh',
#  '₹5.30 Lakh',
#  '₹3.48 Lakh',
#  '₹10.39 Lakh',
#  '₹7.32 Lakh',
#  '₹4.38 Lakh',
#  '₹4 Lakh',
#  '₹11.16 Lakh',
#  '₹6.80 Lakh',
#  '₹12.12 Lakh',
#  '₹10.97 Lakh',
#  '₹10.10 Lakh',
#  '₹9.96 Lakh',
#  '₹3.41 Lakh',
#  '₹3.39 Lakh',
#  '₹9.74 Lakh',
#  '₹10.41 Lakh',
#  '₹10.98 Lakh',
#  '₹6.16 Lakh',
#  '₹10.63 Lakh',
#  '₹9.49 Lakh',
#  '₹10.42 Lakh',
#  '₹18.89 Lakh',
#  '₹19.09 Lakh',
#  '₹19.15 Lakh',
#  '₹17.83 Lakh',
#  '₹19.48 Lakh',
#  '₹7.12 Lakh',
#  '₹10.62 Lakh',
#  '₹3.70 Lakh',
#  '₹7.69 Lakh',
#  '₹8.52 Lakh',
#  '₹5.23 Lakh',
#  '₹12.58 Lakh',
#  '₹4.35 Lakh',
#  '₹4.67 Lakh',
#  '₹4.44 Lakh',
#  '₹9.42 Lakh',
#  '₹3.88 Lakh',
#  '₹6.60 Lakh',
#  '₹9.61 Lakh',
#  '₹5.81 Lakh',
#  '₹7.09 Lakh',
#  '₹3.67 Lakh',
#  '₹3.45 Lakh',
#  '₹5.15 Lakh',
#  '₹5.77 Lakh',
#  '₹4.61 Lakh',
#  '₹6.50 Lakh',
#  '₹6.12 Lakh',
#  '₹4.62 Lakh',
# ...

# %%
cars_4=pd.DataFrame()
cars_4['Names']=names
cars_4['Types']=types
cars_4['Year of purchase']=year
cars_4['Kms run']=kms
cars_4['Price']=price
cars_4['Area']=area
cars_4
# Out:
#                                         Names                 Types  \
# 0                         Mahindra Marazzo M8     m\nDiesel\nManual
# 1     Hyundai Grand i10 Sportz 1.2 Kappa VTVT     m\nPetrol\nManual
# 2                  Hyundai Elite i20 Asta 1.2             m\nPetrol
# 3                      Tata Tiago Revotron XZ     m\nPetrol\nManual
# 4                        Honda WR-V i-DTEC VX        Diesel\nManual
# ..                                        ...                   ...
# 155     Hyundai Creta SX OPT Turbo DCT Petrol  m\nPetrol\nAutomatic
# 156               Tata Tiago Revotron XZ Plus     m\nPetrol\nManual
# 157                        Mahindra XUV500 W8        Diesel\nManual
# 158             Tata Punch Creative Dual Tone     m\nPetrol\nManual
# 159                  Mahindra Scorpio S4 Plus     m\nDiesel\nManual
#
#     Year of purchase    Kms run        Price  \
# 0              2018    91.6K km  ₹10.24 Lakh
# 1              2018    13.4K km   ₹6.31 Lakh
# ...

# %%
button1=driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/div[3]/div[2]/div/div[2]/div/div[1]/div/div/div/button/span[1]')
button1.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in name_tag:
    names.append(i.text[4:])
names
# Out:
# [' Mahindra TUV300 T8 mHAWK100',
#  ' Hyundai Creta 1.6 SX Plus Auto',
#  ' Volkswagen Polo Highline1.2L (P)',
#  ' Volkswagen Vento Highline Diesel',
#  ' Hyundai New i20 Asta 1.2 IVT',
#  ' Datsun Redi-GO T(O) 1.0 AMT',
#  ' Ford EcoSport Titanium 1.5L Ti-VCT',
#  ' Volkswagen Ameo Highline1.2L (P)',
#  ' Ford EcoSport Sports Petrol',
#  ' Volkswagen Polo Comfortline 1.2L (P)',
#  ' Skoda Rapid New Style TDI AT',
#  ' Hyundai Verna Fluidic 1.6 VTVT SX AT',
#  ' Ford EcoSport Titanium + 1.5L TDCi',
#  ' Maruti Suzuki S-Presso VXI+',
#  ' Maruti Suzuki Wagon R 1.0 VXI',
#  ' Maruti Suzuki S-Presso VXI',
#  ' Honda Brio VX MT',
#  ' Maruti Suzuki Ignis Alpha MT Petrol',
#  ' Maruti Suzuki Wagon R 1.0 VXI',
#  ' Toyota Glanza G Hybrid',
#  ' Hyundai Elite i20 Asta 1.2',
#  ' Toyota Glanza G',
#  ' Maruti Suzuki Ciaz Alpha 1.3 Diesel',
#  ' Maruti Suzuki Wagon R 1.0 VXI',
#  ' Hyundai Elite i20 Sportz 1.2',
#  ' Renault Kwid CLIMBER 1.0 AMT Opt',
#  ' Maruti Suzuki Alto 800 VXI',
# ...

# %%
len(names)
# Out:
# 40

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in type_tag:
    types.append(i.text[8:])
types
# Out:
# ['\nDiesel\nManual',
#  '\nDiesel\nAutomatic',
#  '\nPetrol',
#  '\nDiesel\nManual',
#  '\nPetrol\nAutomatic',
#  '\nPetrol',
#  '\nPetrol\nManual',
#  '\nPetrol\nManual',
#  '\nPetrol',
#  '\nPetrol\nManual',
#  '\nDiesel\nAutomatic',
#  '\nPetrol',
#  '\nDiesel\nManual',
#  'Petrol\nManual',
#  '\nPetrol',
#  'etrol\nManual',
#  '\nPetrol\nManual',
#  '\nPetrol',
#  '\nPetrol\nManual',
#  '\nPetrol\nManual',
#  '\nPetrol',
#  'Petrol\nManual',
#  '\nDiesel\nManual',
#  '\nPetrol',
#  '\nPetrol\nManual',
#  'Petrol\nAutomatic',
#  '\nPetrol',
#  '\nPetrol\nManual',
#  '\nPetrol\nManual',
#  '\nPetrol+cng',
#  '\nPetrol\nAutomatic',
#  'etrol\nManual',
#  '\nPetrol',
#  '\nPetrol\nAutomatic',
#  '\nPetrol\nManual',
#  'Petrol',
#  '\nDiesel\nAutomatic',
#  '\nPetrol\nManual',
#  '\nDiesel',
#  '\nPetrol\nAutomatic']

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="styles__otherInfoSection"]')
for i in km_tag:
    kms.append(i.text[0:8])
kms
# Out:
# ['53.3K km',
#  '98.1K km',
#  '65.6K km',
#  '50.9K km',
#  '11.7K km',
#  '35.5K km',
#  '90.4K km',
#  '65.5K km',
#  '69.6K km',
#  '41.4K km',
#  '56.9K km',
#  '53.3K km',
#  '55.2K km',
#  '4.4K km\n',
#  '38.8K km',
#  '34K km\nP',
#  '23.1K km',
#  '40.2K km',
#  '43.3K km',
#  '25.7K km',
#  '97.4K km',
#  '4.3K km\n',
#  '66.6K km',
#  '24.1K km',
#  '20.6K km',
#  '5.5K km\n',
#  '19.4K km',
#  '24.1K km',
#  '21.8K km',
#  '37.7K km',
#  '13.8K km',
#  '33K km\nP',
#  '14.3K km',
#  '19.7K km',
#  '71.2K km',
#  '7.7K km\n',
#  '79.8K km',
#  '36.5K km',
#  '28.6K km',
#  '16.2K km']

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//div[@class="styles__yearAndMakeAndModelSection"]')
for i in year_tag:
    year.append(i.text[0:5])
year
# Out:
# ['2016 ',
#  '2017 ',
#  '2015 ',
#  '2014 ',
#  '2021 ',
#  '2018 ',
#  '2016 ',
#  '2017 ',
#  '2020 ',
#  '2017 ',
#  '2017 ',
#  '2014 ',
#  '2019 ',
#  '2019 ',
#  '2012 ',
#  '2019 ',
#  '2017 ',
#  '2017 ',
#  '2013 ',
#  '2019 ',
#  '2017 ',
#  '2021 ',
#  '2018 ',
#  '2011 ',
#  '2017 ',
#  '2021 ',
#  '2019 ',
#  '2020 ',
#  '2018 ',
#  '2018 ',
#  '2016 ',
#  '2019 ',
#  '2019 ',
#  '2019 ',
#  '2017 ',
#  '2020 ',
#  '2017 ',
#  '2019 ',
#  '2021 ',
#  '2019 ']

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//li[@class="TestDriveAvailability__changeLocationColor"]')
for i in area_tag:
    area.append(i.text)
area
# Out:
# ['Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Park, Hinjewadi, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Elpro City Square Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
#  'Spinny Hub, Seasons Mall, Pune',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//li[@class="styles__price"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹6.78 Lakh',
#  '₹11.32 Lakh',
#  '₹5.72 Lakh',
#  '₹5.19 Lakh',
#  '₹9.69 Lakh',
#  '₹3.77 Lakh',
#  '₹5.80 Lakh',
#  '₹5.38 Lakh',
#  '₹7.94 Lakh',
#  '₹6.11 Lakh',
#  '₹9.66 Lakh',
#  '₹6.01 Lakh',
#  '₹9.27 Lakh',
#  '₹4.88 Lakh',
#  '₹3.41 Lakh',
#  '₹4.86 Lakh',
#  '₹5.44 Lakh',
#  '₹5.44 Lakh',
#  '₹3.75 Lakh',
#  '₹8.06 Lakh',
#  '₹5.93 Lakh',
#  '₹8.51 Lakh',
#  '₹8.97 Lakh',
#  '₹3.17 Lakh',
#  '₹6.83 Lakh',
#  '₹5.50 Lakh',
#  '₹3.71 Lakh',
#  '₹3.88 Lakh',
#  '₹8.61 Lakh',
#  '₹5.18 Lakh',
#  '₹6.39 Lakh',
#  '₹6.05 Lakh',
#  '₹4.29 Lakh',
#  '₹8.25 Lakh',
#  '₹7.72 Lakh',
#  '₹5.41 Lakh',
#  '₹9.22 Lakh',
#  '₹6.49 Lakh',
#  '₹12.09 Lakh',
#  '₹7.85 Lakh']

# %%
cars_5=pd.DataFrame()
cars_5['Names']=names
cars_5['Types']=types
cars_5['Year of purchase']=year
cars_5['Kms run']=kms
cars_5['Price']=price
cars_5['Area']=area
cars_5
# Out:
#                                          Names                Types  \
# 0                  Mahindra TUV300 T8 mHAWK100     \nDiesel\nManual
# 1               Hyundai Creta 1.6 SX Plus Auto  \nDiesel\nAutomatic
# 2             Volkswagen Polo Highline1.2L (P)             \nPetrol
# 3             Volkswagen Vento Highline Diesel     \nDiesel\nManual
# 4                 Hyundai New i20 Asta 1.2 IVT  \nPetrol\nAutomatic
# 5                  Datsun Redi-GO T(O) 1.0 AMT             \nPetrol
# 6           Ford EcoSport Titanium 1.5L Ti-VCT     \nPetrol\nManual
# 7             Volkswagen Ameo Highline1.2L (P)     \nPetrol\nManual
# 8                  Ford EcoSport Sports Petrol             \nPetrol
# 9         Volkswagen Polo Comfortline 1.2L (P)     \nPetrol\nManual
# 10                Skoda Rapid New Style TDI AT  \nDiesel\nAutomatic
# 11        Hyundai Verna Fluidic 1.6 VTVT SX AT             \nPetrol
# 12          Ford EcoSport Titanium + 1.5L TDCi     \nDiesel\nManual
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="0b3435b33df773c3ca083954e70a0e15")>

# %%
driver.maximize_window()

# %%
url='https://www.cars24.com/'
driver.get(url)

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/ul/li[1]')
button.click()

# %%
fill=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/div/div/div/div/div[1]/div/div[2]/div/input')
fill.send_keys("New Delhi")

# %%
butn=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section/div/div/div[2]/button')
butn.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag:
    names.append(i.text)
len(names)
# Out:
# 900

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in type_tag[0:900]:
    types.append(i.text[19:])
len(types)
# Out:
# 900

# %%
types
# Out:
# ['\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-8C',
#  'PETROL\nDL-8C',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-3C',
#  '\nPETROL',
#  'PETROL\nUP-11',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nDIESEL\nHR-26',
#  'PETROL\nHR-26',
#  '\nPETROL',
#  'PETROL\nUP-85',
#  '\nPETROL',
#  '\nPETROL',
#  '\nDIESEL\nHR-26',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nUP-14',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nUP-16',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nHR-51',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-14',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-3C',
#  '\nDIESEL\nDL-4C',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag[0:900]:
    kms.append(i.text[0:10])
len(kms)
kms
# Out:
# ['16,549 KM\n',
#  '22,460 KM\n',
#  '9,417 KM\n1',
#  '7,182 KM\n1',
#  '21,683 KM\n',
#  '12,461 KM\n',
#  '12,170 KM\n',
#  '6,920 KM\n1',
#  '18,469 KM\n',
#  '3,084 KM\n1',
#  '12,742 KM\n',
#  '26,424 KM\n',
#  '21,670 KM\n',
#  '38,501 KM\n',
#  '22,752 KM\n',
#  '48,810 KM\n',
#  '46,061 KM\n',
#  '62,075 KM\n',
#  '25,750 KM\n',
#  '36,434 KM\n',
#  '33,528 KM\n',
#  '28,506 KM\n',
#  '53,930 KM\n',
#  '6,978 KM\n1',
#  '12,835 KM\n',
#  '6,063 KM\n1',
#  '13,672 KM\n',
#  '41,378 KM\n',
#  '49,350 KM\n',
#  '93,626 KM\n',
#  '39,585 KM\n',
#  '37,099 KM\n',
#  '6,793 KM\n1',
#  '73,738 KM\n',
#  '26,517 KM\n',
#  '15,597 KM\n',
#  '25,090 KM\n',
#  '13,095 KM\n',
#  '12,717 KM\n',
#  '28,979 KM\n',
#  '22,904 KM\n',
#  '2,461 KM\n1',
#  '23,355 KM\n',
#  '59,449 KM\n',
#  '14,123 KM\n',
#  '1,994 KM\n2',
#  '59,025 KM\n',
#  '23,486 KM\n',
#  '2,424 KM\n1',
#  '10,559 KM\n',
#  '18,495 KM\n',
#  '21,250 KM\n',
#  '61,606 KM\n',
#  '26,495 KM\n',
#  '4,921 KM\n1',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag[0:900]:
    year.append(i.text[0:4])
len(year)
year
# Out:
# ['2018',
#  '2016',
#  '2020',
#  '2021',
#  '2014',
#  '2020',
#  '2015',
#  '2014',
#  '2020',
#  '2022',
#  '2021',
#  '2020',
#  '2014',
#  '2012',
#  '2021',
#  '2016',
#  '2016',
#  '2011',
#  '2019',
#  '2019',
#  '2011',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2019',
#  '2013',
#  '2020',
#  '2015',
#  '2019',
#  '2013',
#  '2021',
#  '2011',
#  '2020',
#  '2020',
#  '2019',
#  '2020',
#  '2021',
#  '2013',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2021',
#  '2019',
#  '2014',
#  '2018',
#  '2022',
#  '2021',
#  '2011',
#  '2013',
#  '2016',
#  '2020',
#  '2020',
#  '2021',
#  '2012',
#  '2012',
#  '2020',
#  '2018',
#  '2020',
#  '2021',
#  '2012',
#  '2010',
#  '2011',
#  '2016',
#  '2021',
#  '2014',
#  '2020',
#  '2014',
#  '2020',
#  '2022',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2020',
#  '2021',
#  '2015',
#  '2020',
#  '2021',
#  '2021',
#  '2017',
#  '2019',
#  '2017',
#  '2013',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
# ...

# %%
len(year)
# Out:
# 900

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//div[@class="_351jJ"]')
for i in area_tag[0:900]:
    area.append(i.text)
len(area)
# Out:
# 900

# %%
area
# Out:
# ['Sector-18, Noida',
#  'Parsvnath City Mall, Faridabad',
#  'Sector-18, Noida',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'GIP Mall, Noida',
#  'Sector-18, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Spaze Platinum, Gurgaon',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Parsvnath City Mall, Faridabad',
#  'Ansal API, Gurgaon',
#  'GIP Mall, Noida',
#  'Ansal API, Gurgaon',
#  'Sector-18, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'Ansal API, Gurgaon',
#  'Spaze Platinum, Gurgaon',
#  'Sector-18, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'Ansal API, Gurgaon',
#  'Spaze Platinum, Gurgaon',
#  'Parsvnath City Mall, Faridabad',
#  'Spaze Platinum, Gurgaon',
#  'Ansal API, Gurgaon',
#  'Spaze Platinum, Gurgaon',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag[0:900]:
    price.append(i.text)
len(price)
# Out:
# 900

# %%
price
# Out:
# ['₹2,30,000',
#  '₹2,41,000',
#  '₹16,73,000\n₹18,58,000',
#  '₹17,01,000\n₹18,22,000',
#  '₹2,73,000',
#  '₹13,39,000',
#  '₹3,36,000',
#  '₹2,72,000',
#  '₹16,91,000\n₹18,21,000',
#  '₹17,42,000\n₹18,67,000',
#  '₹5,90,000',
#  '₹5,88,000',
#  '₹2,78,000',
#  '₹4,12,000',
#  '₹14,07,000\n₹14,13,000',
#  '₹2,36,000',
#  '₹2,59,000',
#  '₹2,88,000',
#  '₹10,57,000\n₹11,30,000',
#  '₹16,88,000\n₹17,01,000',
#  '₹2,74,000\n₹2,79,000',
#  '₹16,42,000\n₹17,58,000',
#  '₹17,12,000',
#  '₹12,51,000\n₹12,63,000',
#  '₹13,38,000',
#  '₹8,56,000\n₹8,91,000',
#  '₹15,37,000\n₹15,90,000',
#  '₹2,88,000',
#  '₹14,36,000',
#  '₹12,43,000\n₹12,79,000',
#  '₹10,97,000\n₹11,26,000',
#  '₹3,94,000',
#  '₹10,07,000',
#  '₹2,70,000',
#  '₹13,64,000',
#  '₹10,80,000',
#  '₹10,57,000\n₹11,37,000',
#  '₹4,86,000\n₹5,08,000',
#  '₹8,26,000',
#  '₹3,09,000',
#  '₹10,94,000\n₹11,46,000',
#  '₹10,18,000\n₹11,10,000',
#  '₹6,69,000\n₹7,29,000',
#  '₹10,15,000\n₹10,56,000',
#  '₹8,59,000',
#  '₹5,66,000',
# ...

# %%
cars_6=pd.DataFrame()
cars_6['Names']=names
cars_6['Types']=types
cars_6['Year of purchase']=year
cars_6['Kms run']=kms
cars_6['Price']=price
cars_6['Area']=area
cars_6
# Out:
#                        Names          Types Year of purchase      Kms run  \
# 0        2018 DATSUN REDI GO       \nPETROL             2018  16,549 KM\n
# 1          2016 Renault Kwid       \nPETROL             2016  22,460 KM\n
# 2            2020 KIA SELTOS  PETROL\nDL-8C             2020  9,417 KM\n1
# 3          2021 Skoda KUSHAQ  PETROL\nDL-8C             2021  7,182 KM\n1
# 4       2014 Maruti ALTO K10       \nPETROL             2014  21,683 KM\n
# ..                       ...            ...              ...          ...
# 895       2016 Hyundai Creta       \nPETROL             2016  78,700 KM\n
# 896  2019 Hyundai NEW SANTRO   \nCNG\nDL-7C             2019  36,443 KM\n
# 897      2018 Maruti Celerio   \nCNG\nDL-8C             2018  50,844 KM\n
# 898  2019 HYUNDAI NEW SANTRO   \nCNG\nDL-12             2019  39,906 KM\n
# 899       2020 Maruti Baleno       \nPETROL             2020  39,687 KM\n
#
#                       Price                            Area
# ...

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section/div/div/div[2]/button')
button.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag:
    names.append(i.text[4:])
len(names)
# Out:
# 820

# %%
names
# Out:
# [' Honda City',
#  ' Maruti Swift Dzire',
#  ' Tata Tiago',
#  ' Renault Kwid',
#  ' Hyundai i20',
#  ' Maruti Alto',
#  ' Skoda Rapid',
#  ' Maruti Dzire',
#  ' Maruti Alto 800',
#  ' HYUNDAI I20',
#  ' Honda City',
#  ' Maruti Swift Dzire',
#  ' Ford Ecosport',
#  ' Maruti Alto K10',
#  ' Maruti Wagon R 1.0',
#  ' Hyundai i10',
#  ' Hyundai Creta',
#  ' DATSUN REDI GO',
#  ' Renault Kwid',
#  ' Hyundai i10',
#  ' Hyundai Verna',
#  ' Maruti Swift',
#  ' Maruti Swift',
#  ' Honda BR-V',
#  ' Maruti Dzire',
#  ' Maruti New Wagon-R',
#  ' Renault Kwid',
#  ' Mahindra MARAZZO',
#  ' Renault Pulse',
#  ' Tata NEXON',
#  ' Hyundai Elite i20',
#  ' Volkswagen Polo',
#  ' Hyundai Grand i10',
#  ' Maruti SWIFT DZIRE',
#  ' Nissan Micra',
#  ' Maruti Baleno',
#  ' Maruti Alto 800',
#  ' Toyota Etios Liva',
#  ' Maruti VITARA BREZZA',
#  ' Hyundai ALCAZAR',
#  ' Maruti Swift',
#  ' Volkswagen Ameo',
#  ' Maruti IGNIS',
#  ' HYUNDAI NEW SANTRO',
#  ' Tata PUNCH',
#  ' Hyundai Creta',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag:
    year.append(i.text[0:5])
len(year)
# Out:
# 820

# %%
year
# Out:
# ['2017 ',
#  '2012 ',
#  '2018 ',
#  '2017 ',
#  '2012 ',
#  '2010 ',
#  '2016 ',
#  '2017 ',
#  '2012 ',
#  '2011 ',
#  '2011 ',
#  '2016 ',
#  '2014 ',
#  '2013 ',
#  '2013 ',
#  '2014 ',
#  '2021 ',
#  '2017 ',
#  '2016 ',
#  '2014 ',
#  '2021 ',
#  '2015 ',
#  '2019 ',
#  '2017 ',
#  '2017 ',
#  '2019 ',
#  '2017 ',
#  '2020 ',
#  '2016 ',
#  '2019 ',
#  '2017 ',
#  '2016 ',
#  '2013 ',
#  '2015 ',
#  '2017 ',
#  '2020 ',
#  '2013 ',
#  '2017 ',
#  '2016 ',
#  '2021 ',
#  '2011 ',
#  '2016 ',
#  '2017 ',
#  '2020 ',
#  '2021 ',
#  '2017 ',
#  '2015 ',
#  '2017 ',
#  '2016 ',
#  '2015 ',
#  '2018 ',
#  '2016 ',
#  '2012 ',
#  '2020 ',
#  '2020 ',
#  '2011 ',
#  '2017 ',
#  '2014 ',
#  '2015 ',
#  '2012 ',
#  '2018 ',
#  '2015 ',
#  '2018 ',
#  '2015 ',
#  '2019 ',
#  '2014 ',
#  '2013 ',
#  '2012 ',
#  '2016 ',
#  '2014 ',
#  '2019 ',
#  '2014 ',
#  '2013 ',
#  '2016 ',
#  '2016 ',
#  '2020 ',
#  '2016 ',
#  '2020 ',
#  '2017 ',
#  '2013 ',
#  '2021 ',
#  '2012 ',
#  '2016 ',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in type_tag:
    types.append(i.text[19:27])
len(types)
# Out:
# 820

# %%
types
# Out:
# ['\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  'PETROL\nK',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  'PETROL\nK',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  'PETROL\nK',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nPETROL\n',
#  '\nDIESEL\n',
#  '\nDIESEL\n',
#  '\nPETROL\n',
# ...

# %%
types
# Out:
# ['\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  'Petrol\nK',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  'Petrol\nK',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  'Petrol\nK',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  'Petrol\nK',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
#  '\nPetrol\n',
#  '\nPetrol\n',
#  '\nDiesel\n',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag:
    kms.append(i.text[0:10])
len(kms)
# Out:
# 820

# %%
kms
# Out:
# ['63,810 KM\n',
#  '80,087 KM\n',
#  '77,365 KM\n',
#  '46,397 KM\n',
#  '78,221 KM\n',
#  '63,805 KM\n',
#  '89,531 KM\n',
#  '31,330 KM\n',
#  '38,408 KM\n',
#  '91,829 KM\n',
#  '43,249 KM\n',
#  '48,294 KM\n',
#  '68,103 KM\n',
#  '43,628 KM\n',
#  '60,194 KM\n',
#  '44,617 KM\n',
#  '20,205 KM\n',
#  '30,331 KM\n',
#  '61,266 KM\n',
#  '89,433 KM\n',
#  '24,255 KM\n',
#  '22,873 KM\n',
#  '14,148 KM\n',
#  '19,947 KM\n',
#  '60,341 KM\n',
#  '9,723 KM\n1',
#  '26,915 KM\n',
#  '22,707 KM\n',
#  '41,023 KM\n',
#  '23,963 KM\n',
#  '38,571 KM\n',
#  '69,375 KM\n',
#  '99,287 KM\n',
#  '79,214 KM\n',
#  '31,476 KM\n',
#  '11,400 KM\n',
#  '80,700 KM\n',
#  '34,844 KM\n',
#  '67,996 KM\n',
#  '5,197 KM\n1',
#  '89,179 KM\n',
#  '28,444 KM\n',
#  '68,362 KM\n',
#  '11,932 KM\n',
#  '9,747 KM\n1',
#  '54,913 KM\n',
#  '71,508 KM\n',
#  '26,353 KM\n',
#  '54,681 KM\n',
#  '73,736 KM\n',
#  '42,999 KM\n',
#  '49,854 KM\n',
#  '31,543 KM\n',
#  '13,556 KM\n',
#  '17,147 KM\n',
# ...

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//span[@class="_3DYbK"]')
for i in area_tag[0:820]:
    area.append(i.text)
len(area)
# Out:
# 820

# %%
area
# Out:
# ['GT World Mall, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'GT World Mall, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'Garuda Mall, Magrath Road',
#  'Bellahalli, Bengaluru',
#  'GT World Mall, Bengaluru',
#  'Horamavu Agara Road, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Bellahalli, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
#  'Bellahalli, Bengaluru',
#  'Whitefield Main Road, Bhoruka Tech Park',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag[0:820]:
    price.append(i.text)
len(price)
# Out:
# 820

# %%
cars_7=pd.DataFrame()
cars_7['Names']=names
cars_7['Types']=types
cars_7['Year of purchase']=year
cars_7['Kms run']=kms
cars_7['Price']=price
cars_7['Area']=area
cars_7
# Out:
#                    Names       Types Year of purchase      Kms run  \
# 0             Honda City  \nPETROL\n            2017   63,810 KM\n
# 1     Maruti Swift Dzire  \nDIESEL\n            2012   80,087 KM\n
# 2             Tata Tiago  \nPETROL\n            2018   77,365 KM\n
# 3           Renault Kwid  \nPETROL\n            2017   46,397 KM\n
# 4            Hyundai i20  \nDIESEL\n            2012   78,221 KM\n
# ..                   ...         ...              ...          ...
# 815        Maruti Baleno   PETROL\nK            2020   7,078 KM\n1
# 816        Maruti Baleno  \nPETROL\n            2017   19,957 KM\n
# 817          Maruti Ritz  \nPETROL\n            2010   44,344 KM\n
# 818       Renault Duster  \nPETROL\n            2020   20,743 KM\n
# 819         Renault Kwid  \nPETROL\n            2018   59,635 KM\n
#
#                     Price                                     Area
# 0               ₹7,77,000                 GT World Mall, Bengaluru
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="a78d568efdfedaaa9dabae03179e0a77")>

# %%
driver.maximize_window()

# %%
url='https://www.truevalue.com/'
driver.get(url)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e0459aa709b5079658e7e5ed24a0c035")>

# %%
driver.maximize_window()

# %%
url='https://www.edmunds.com/'
driver.get(url)

# %%
btn=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/nav/div[2]/div/ul/li[2]/a/span')
btn.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="mb-0"]')
for i in name_tag:
    names.append(i.text[5:])
len(names)
# Out:
# 21

# %%
names
# Out:
# ['Ford Mustang\nMach 1 Coupe',
#  'Ford F-150\nXLT SuperCrew',
#  'fied 2021 Jeep Wrangler\nSport S Convertible SUV',
#  'Ram 1500\nTRX Crew Cab',
#  'Ram 2500\nBig Horn Diesel Mega Cab',
#  'Dodge Journey\nCrossroad Plus 4dr SUV',
#  'Subaru Outback\nLimited 4dr SUV',
#  'Chevrolet Silverado 1500\nLT Crew Cab',
#  'Chevrolet Silverado 1500\nLT Trail Boss Crew Cab',
#  'Jeep Wrangler\nSport S Convertible SUV',
#  'Toyota Prius\nTwo Hybrid 4dr Hatchback',
#  'Nissan Altima\n2.5 S Sedan',
#  'Ram 1500 Classic\nWarlock Quad Cab',
#  'Toyota Corolla\nLE Sedan',
#  'Nissan Frontier\nSV Crew Cab',
#  'Lexus NX 200t\nBase 4dr SUV',
#  'Ram 1500\nRebel Crew Cab',
#  'Kia Sorento\nEX 4dr SUV',
#  'Honda Accord\nEX-L Sedan',
#  'Honda Ridgeline\nRTL-E Crew Cab',
#  'Dodge Grand Caravan\nSE Plus Passenger Minivan']

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="mb-0"]')
for i in year_tag:
    year.append(i.text[0:5])
len(year)
# Out:
# 21

# %%
year
# Out:
# ['2022 ',
#  '2019 ',
#  'Certi',
#  '2022 ',
#  '2022 ',
#  '2016 ',
#  '2020 ',
#  '2019 ',
#  '2021 ',
#  '2020 ',
#  '2018 ',
#  '2020 ',
#  '2020 ',
#  '2011 ',
#  '2019 ',
#  '2017 ',
#  '2016 ',
#  '2008 ',
#  '2020 ',
#  '2019 ',
#  '2018 ']

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//div[@class="key-point size-14 d-flex align-items-baseline mt-0_5 col-12"]')
for i in type_tag:
    types.append(i.text[0:4])
len(types)
# Out:
# 84

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="f3e86b9496a3b76dfec664cb185f4345")>

# %%
driver.maximize_window()

# %%
url='https://www.olx.com/'
driver.get(url)

# %%
button=driver.find_element(By.XPATH,'/html/body/div/div/header/div/div/div[2]/div/div/div[2]/div/form/fieldset/div/input')
button.send_keys("cars")

# %%
btn=driver.find_element(By.XPATH,'/html/body/div/div/header/div/div/div[2]/div/div/div[3]')
btn.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for i in name_tag[0:288]:
    names.append(i.text)
len(names)
# Out:
# 288

# %%
names
# Out:
# ['Honda City 2011-2013 V MT, 2010, Petrol',
#  'Honda Jazz 1.2 S i VTEC, 2012, Petrol',
#  'Honda CR-V 2007-2012 MT With Sun Roof, 2008, Petrol',
#  'Honda Amaze 2020 Petrol',
#  'Honda City ZX 2005 Petrol',
#  'Honda Amaze S MT i-VTEC, 2017, Petrol',
#  '3bhk 90sq/yard first floor with lift and car parking nearby dwarka mor',
#  '2bhk (55sq yard) 2bhk with lift and car parking PRIME location',
#  'My personal car good condition',
#  'Single Owner Honda City (2007)',
#  'My Car is of full maintenance and in good condition',
#  '3Bhk flat at Bhutnath Road @4700/sft. Car parking available',
#  'Create car automatic',
#  'Laggage carrier for all car',
#  'Honda City 2008-2011 1.5 V AT, 2009, CNG & Hybrids',
#  'Honda City 2015 Petrol',
#  'Honda City VX sunroof 2019 Diesel Well Maintained',
#  'Maruti Suzuki Alto 800 STD BSIV best maintend car.',
#  'Honda Jazz 2016 Petrol 58000 Km Driven',
#  '2 bhk with car parking',
#  'Honda City VX (O) MT I-VTEC, 2023, Petrol',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//span[@class="YBbhy"]')
for i in km_tag:
    kms.append(i.text[4:])
len(kms)
# Out:
# 288

# %%
kms
# Out:
# [' - 62,000 km',
#  ' - 76000.0 km',
#  ' - 69,000 km',
#  ' - 10,000 km',
#  ' - 140,000 km',
#  ' - 63,300 km',
#  's - 2 Ba - 900 ft2',
#  's - 2 Ba - 550 ft2',
#  ' - 74,411 km',
#  ' - 73,900 km',
#  ' - 70,000 km',
#  's - 2 Ba - 1130 ft2',
#  '000 - 30000 | Monthly',
#  ' - 87000.0 km',
#  ' - 120,000 km',
#  ' - 84,000 km',
#  ' - 154,000 km',
#  ' - 58,000 km',
#  's - 2 Ba - 555 ft2',
#  ' - 2,500 km',
#  ' - 19,000 km',
#  ' - 75,000 km',
#  ' - 85,000 km',
#  's - 2 Ba - 930 ft2',
#  ' - 130,000 km',
#  ' - 55,000 km',
#  ' - 75,000 km',
#  ' - 62000.0 km',
#  ' - 44,000 km',
#  ' - 60,134 km',
#  ' - 78,000 km',
#  ' - 49,000 km',
#  ' - 109,412 km',
#  's - 2 Ba - 900 ft2',
#  ' - 68,000 km',
#  's - 2 Ba - 600 ft2',
#  ' - 65000.0 km',
#  ' - 78000.0 km',
#  ' - 80,000 km',
#  ' - 50,000 km',
#  ' - 120,000 km',
#  ' - 67000.0 km',
#  ' - 46,866 km',
#  ' - 85000.0 km',
#  ' - 68933.0 km',
#  ' - 79987.0 km',
#  ' - 68,000 km',
#  ' - 87139.0 km',
#  ' - 50364.0 km',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//span[@class="YBbhy"]')
for i in year_tag:
    year.append(i.text[0:5])
len(year)
# Out:
# 288

# %%
year
# Out:
# ['2010 ',
#  '2012 ',
#  '2008 ',
#  '2020 ',
#  '2005 ',
#  '2017 ',
#  '3 Bds',
#  '2 Bds',
#  '2012 ',
#  '2007 ',
#  '2020 ',
#  '3 Bds',
#  '₹ 250',
#  '2009 ',
#  '2015 ',
#  '2019 ',
#  '2013 ',
#  '2016 ',
#  '2 Bds',
#  '2023 ',
#  '2018 ',
#  '2013 ',
#  '2011 ',
#  '2 Bds',
#  '2008 ',
#  '2016 ',
#  '2012 ',
#  '2009 ',
#  '2012 ',
#  '2013 ',
#  '2014 ',
#  '2019 ',
#  '2010 ',
#  '3 Bds',
#  '2009 ',
#  '2 Bds',
#  '2020 ',
#  '2010 ',
#  '2008 ',
#  '2016 ',
#  '2019 ',
#  '2016 ',
#  '2017 ',
#  '2009 ',
#  '2011 ',
#  '2012 ',
#  '2010 ',
#  '2016 ',
#  '2018 ',
#  '2008 ',
#  '2017 ',
#  '2018 ',
#  '2018 ',
#  '2009 ',
#  '2018 ',
#  '2018 ',
#  '2015 ',
#  '2014 ',
#  '2014 ',
#  '2010 ',
#  '2007 ',
#  '2014 ',
#  '2014 ',
#  '2018 ',
#  '2014 ',
#  '2011 ',
#  '2017 ',
#  '2014 ',
#  '2015 ',
#  '2010 ',
#  '2017 ',
#  '2015 ',
#  '2014 ',
#  '2013 ',
#  '2019 ',
#  '2018 ',
#  '₹ 800',
#  '2014 ',
#  '2010 ',
#  '2014 ',
#  '2017 ',
#  '2014 ',
#  '2023 ',
# ...

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//span[@class="_2VQu4"]')
for i in area_tag[0:288]:
    area.append(i.text)
len(area)
# Out:
# 288

# %%
area
# Out:
# ['PANDIAN NAGAR, TIRUPPUR',
#  'RTC COLONY, HYDERABAD',
#  'PALLAV COLONY, DEHRADUN',
#  'E BLOCKS, JHAKHRI',
#  'GHATKOPAR WEST, MUMBAI',
#  'VASHI, NAVI MUMBAI',
#  'DWARKA MOR, DELHI',
#  'DWARKA MOR, DELHI',
#  'AKASHVANI COLONY, CHURU',
#  'KARIMKUNNAM, THODUPUZHA',
#  'BANAMALI PART 1, KARIMGANJ',
#  'SANTIPUR, GUWAHATI',
#  'KISHANGARH, DELHI',
#  'DAS SARAI, MORADABAD',
#  'SHAHIBAG, AHMEDABAD',
#  'GAJUWAKA, VISAKHAPATNAM',
#  'ALIGANJ, LUCKNOW',
#  'JIJAMATA NAGAR, HINGOLI',
#  'NIRVANA, GURGAON',
#  'MANSA RAM PARK, DELHI',
#  'INDUSTRIAL AREA, CHANDIGARH',
#  'NAGOLE, HYDERABAD',
#  'CALICUT CIVIL STATION, KOZHIKODE',
#  'BHARATRATNA DR B AMBEDKAR CHOWK, NASHIK',
#  'MANSAROVAR, JAIPUR',
#  'MANSA RAM PARK, DELHI',
#  'THIRUMAL NAGAR, TIRUNELVELI',
#  'ITO, DELHI',
#  'BANER, PUNE',
#  'PATRAKAR COLONY, JODHPUR',
#  'SECTOR 7 EXTENSION, GURGAON',
#  'KALIGHAT SOUTH EAST, KOLKATA',
#  'SECTOR 37, FARIDABAD',
#  'RAJOURI GARDEN, DELHI',
#  'DAHISAR EAST, MUMBAI',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//span[@class="_2poNJ"]')
for i in type_tag[0:288]:
    types.append(i.text)
len(types)
# Out:
# 288

# %%
types
# Out:
# [' 2017, Petrol',
#  '16, Diesel',
#  ' 2020, Petrol',
#  'TEC CVT VX, 2015, Petrol',
#  '-DTEC, 2015, Diesel',
#  ' S MT, 2009, Petrol',
#  ' V MT, 2011, CNG & Hybrids',
#  '17, Diesel',
#  ' Petrol',
#  'l',
#  'EC, 2015, Petrol',
#  '18, Petrol',
#  ' Petrol',
#  'TEC SV, 2016, Petrol',
#  ' sale',
#  'rsary Edition, 2018, Petrol',
#  ' 2017, Petrol',
#  'Diesel Well Maintained',
#  'ybrids Good Condition',
#  'First Owner.Top Model',
#  ', 2016, Diesel',
#  'EC, 2015, Diesel',
#  'etrol',
#  'c, 2021, Petrol',
#  ' Petrol',
#  '6, Petrol',
#  '18, Petrol',
#  '2011, CNG & Hybrids',
#  ' V AT, 2009, Petrol',
#  'TEC VX Option, 2016, Petrol',
#  'petrol',
#  '22, Petrol',
#  'iler',
#  'AVN), 2018, Petrol',
#  'tereo System',
#  'R',
#  'etrol',
#  '2015, Diesel',
#  'EC, 2017, Petrol',
#  'i-Vtech, 2013, Petrol',
#  'TEC, 2014, Petrol',
#  'etrol',
#  '5, Petrol',
#  '',
#  ' S MT, 2011, CNG & Hybrids',
#  ' 2015, Petrol',
#  ', 2016, CNG & Hybrids',
#  ', 2019, Petrol',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//span[@class="_2Ks63"]')
for i in price_tag[0:288]:
    price.append(i.text)
len(price)
# Out:
# 288

# %%
price
# Out:
# ['₹ 4,10,000',
#  '₹ 3,25,000',
#  '₹ 3,90,000',
#  '₹ 6,50,000',
#  '₹ 99,000',
#  '₹ 5,55,000',
#  '₹ 36,75,000',
#  '₹ 23,50,000',
#  '₹ 40,000',
#  '₹ 2,65,000',
#  '₹ 6,30,000',
#  '₹ 51,00,000',
#  '₹ 2,500',
#  '₹ 3,00,000',
#  '₹ 3,50,000',
#  '₹ 9,85,000',
#  '₹ 1,50,000',
#  '₹ 4,90,000',
#  '₹ 28,81,000',
#  '₹ 13,50,000',
#  '₹ 7,85,000',
#  '₹ 4,40,000',
#  '₹ 5,50,000',
#  '₹ 42,10,000',
#  '₹ 1,90,000',
#  '₹ 6,85,000',
#  '₹ 3,00,000',
#  '₹ 2,70,000',
#  '₹ 15,000',
#  '₹ 1,89,000',
#  '₹ 4,20,000',
#  '₹ 2,50,000',
#  '₹ 8,60,000',
#  '₹ 4,75,000',
#  '₹ 49,99,000',
#  '₹ 1,75,000',
#  '₹ 24,75,000',
#  '₹ 7,50,000',
#  '₹ 2,91,000',
#  '₹ 8,596',
#  '₹ 1,30,000',
#  '₹ 6,80,000',
#  '₹ 9,50,000',
#  '₹ 7,25,000',
#  '₹ 8,65,000',
#  '₹ 3,99,000',
#  '₹ 4,00,000',
#  '₹ 3,00,000',
#  '₹ 3,75,000',
#  '₹ 7,55,000',
#  '₹ 8,36,000',
#  '₹ 2,65,000',
#  '₹ 6,90,000',
#  '₹ 5,73,000',
#  '₹ 8,75,000',
#  '₹ 2,49,000',
#  '₹ 7,90,000',
#  '₹ 8,30,000',
#  '₹ 7,50,000',
# ...

# %%
cars_8=pd.DataFrame()
cars_8['Names']=names
cars_8['Types']=types
cars_8['Year of purchase']=year
cars_8['Kms run']=kms
cars_8['Price']=price
cars_8['Area']=area
cars_8
# Out:
#                                                  Names  \
# 0              Honda City 2011-2013 V MT, 2010, Petrol
# 1                Honda Jazz 1.2 S i VTEC, 2012, Petrol
# 2    Honda CR-V 2007-2012 MT With Sun Roof, 2008, P...
# 3                              Honda Amaze 2020 Petrol
# 4                            Honda City ZX 2005 Petrol
# ..                                                 ...
# 283              Honda City SV MT I-VTEC, 2017, Petrol
# 284            Honda Brio 2011-2013 S MT, 2013, Petrol
# 285        Honda City 2008-2011 1.5 S AT, 2009, Petrol
# 286                    Honda Jazz Others, 2010, Petrol
# 287               Honda BR-V i-VTEC S MT, 2017, Petrol
#
#                                                  Types Year of purchase  \
# 0              Honda City 2011-2013 V MT, 2010, Petrol            2010
# 1                Honda Jazz 1.2 S i VTEC, 2012, Petrol            2012
# 2    Honda CR-V 2007-2012 MT With Sun Roof, 2008, P...            2008
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="15ad527aaded71b17cfc24f004038957")>

# %%
driver.maximize_window()

# %%
url='https://www.cardekho.com/'
driver.get(url)

# %%
button=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/div/div[1]/div/div[2]/div')
button.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h3[@class="title"]')
for i in name_tag:
    names.append(i.text[5:])
len(names)
# Out:
# 840

# %%
names
# Out:
# ['Renault Duster Petrol RxL',
#  'Ford Ecosport 1.5 DV5 MT Titanium',
#  'Kia Carnival Prestige 6 STR',
#  'Maruti Alto 800 CNG LXI',
#  'Honda Amaze S Petrol BSIV',
#  'Audi A4 30 TFSI Technology',
#  'Hyundai Grand i10 1.2 Kappa Sportz Option AT',
#  'Hyundai Grand i10 Nios Magna',
#  'Hyundai Verna VTVT 1.6 SX',
#  'Mahindra XUV500 W11 Option AT AWD',
#  'Maruti Ignis 1.2 Delta BSIV',
#  'Hyundai Verna CRDi 1.6 SX',
#  'Honda Amaze S Petrol BSIV',
#  'Jeep Compass 2.0 Limited Plus',
#  'Land Rover Range Rover Evoque 2.2L Dynamic',
#  'BMW 6 Series GT 620d Luxury Line 2019-2021',
#  'Honda WR-V i-VTEC VX',
#  'Volvo XC60 D5 Inscription',
#  'Mercedes-Benz E-Class Exclusive E 220 d BSIV',
#  'BMW X7 xDrive 40i',
#  'Tata Nexon 1.5 Revotorq XM',
#  'Hyundai i10 Magna',
#  'Hyundai Creta 1.4 EX Diesel',
#  'Toyota Innova Crysta 2.8 ZX AT BSIV',
#  'Hyundai i10 Magna 1.2 iTech SE',
#  'Mahindra Bolero Pik Up Extra Long FB 1.25T',
#  'Hyundai Grand i10 1.2 Kappa Magna CNG BSIV',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h3[@class="title"]')
for i in year_tag:
    year.append(i.text[0:5])
len(year)
# Out:
# 840

# %%
year
# Out:
# ['2013 ',
#  '2014 ',
#  '2020 ',
#  '2013 ',
#  '2019 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2018 ',
#  '2018 ',
#  '2020 ',
#  '2019 ',
#  '2019 ',
#  '2019 ',
#  '2013 ',
#  '2020 ',
#  '2019 ',
#  '2020 ',
#  '2017 ',
#  '2019 ',
#  '2017 ',
#  '2013 ',
#  '2019 ',
#  '2018 ',
#  '2011 ',
#  '2021 ',
#  '2020 ',
#  '2021 ',
#  '2011 ',
#  '2019 ',
#  '2018 ',
#  '2019 ',
#  '2019 ',
#  '2020 ',
#  '2017 ',
#  '2021 ',
#  '2021 ',
#  '2018 ',
#  '2019 ',
#  '2021 ',
#  '2019 ',
#  '2020 ',
#  '2016 ',
#  '2019 ',
#  '2020 ',
#  '2011 ',
#  '2019 ',
#  '2019 ',
#  '2014 ',
#  '2019 ',
#  '2018 ',
#  '2018 ',
#  '2017 ',
#  '2017 ',
#  '2015 ',
#  '2015 ',
#  '2015 ',
#  '2020 ',
#  '2019 ',
#  '2018 ',
#  '2019 ',
#  '2015 ',
#  '2014 ',
#  '2017 ',
#  '2012 ',
#  '2015 ',
#  '2015 ',
#  '2020 ',
#  '2018 ',
#  '2016 ',
#  '2011 ',
#  '2015 ',
#  '2017 ',
#  '2012 ',
#  '2016 ',
#  '2018 ',
#  '2016 ',
#  '2017 ',
#  '2018 ',
#  '2021 ',
#  '2010 ',
#  '2012 ',
#  '2016 ',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//div[@class="dotsDetails"]')
for i in type_tag:
    types.append(i.text[11:])
len(types)
# Out:
# 840

# %%
types
# Out:
# ['• Petrol • Manual',
#  '• Diesel • Manual',
#  '• Diesel • Automatic',
#  '• CNG • Manual',
#  '• Petrol • Manual',
#  '• Petrol • Automatic',
#  '• Petrol • Automatic',
#  '• Petrol • Manual',
#  '• Petrol • Manual',
#  '• Diesel • Automatic',
#  '• Petrol • Manual',
#  '• Diesel • Manual',
#  '• Petrol • Manual',
#  '• Diesel • Manual',
#  '• Diesel • Automatic',
#  '• Diesel • Automatic',
#  '• Petrol • Manual',
#  '• Diesel • Automatic',
#  '• Diesel • Automatic',
#  '• Petrol • Automatic',
#  '• Diesel • Manual',
#  '• Petrol • Manual',
#  '• Diesel • Manual',
#  '• Diesel • Automatic',
#  '• Petrol • Manual',
#  ' Diesel • Manual',
#  '• CNG • Manual',
#  '• Diesel • Automatic',
#  '• Petrol • Automatic',
#  ' Petrol • Manual',
#  '• Diesel • Automatic',
#  '• Diesel • Automatic',
#  '• Diesel • Manual',
#  '• Petrol • Manual',
#  '• Petrol • Automatic',
#  '• Petrol • Automatic',
#  '• Petrol • Automatic',
#  ' Diesel • Manual',
#  '• Diesel • Manual',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//div[@class="dotsDetails"]')
for i in km_tag:
    kms.append(i.text[0:11])
len(kms)
# Out:
# 840

# %%
kms
# Out:
# ['59,738 kms ',
#  '71,000 kms ',
#  '49,000 kms ',
#  '65,000 kms ',
#  '14,000 kms ',
#  '23,000 kms ',
#  '45,000 kms ',
#  '13,000 kms ',
#  '57,700 kms ',
#  '53,213 kms ',
#  '40,000 kms ',
#  '36,000 kms ',
#  '35,000 kms ',
#  '35,963 kms ',
#  '60,000 kms ',
#  '50,000 kms ',
#  '28,000 kms ',
#  '15,000 kms ',
#  '43,000 kms ',
#  '36,785 kms ',
#  '50,123 kms ',
#  '65,000 kms ',
#  '52,000 kms ',
#  '85,000 kms ',
#  '64,000 kms ',
#  '3,500 kms •',
#  '43,000 kms ',
#  '10,000 kms ',
#  '60,000 kms ',
#  '4,000 kms •',
#  '73,253 kms ',
#  '34,000 kms ',
#  '59,201 kms ',
#  '16,325 kms ',
#  '75,000 kms ',
#  '12,000 kms ',
#  '36,000 kms ',
#  '8,100 kms •',
#  '65,000 kms ',
#  '1,600 kms •',
#  '38,000 kms ',
#  '16,000 kms ',
#  '67,000 kms ',
#  '23,000 kms ',
#  '11,000 kms ',
#  '1,20,000 km',
#  '47,000 kms ',
#  '60,000 kms ',
#  '95,000 kms ',
#  '79,000 kms ',
#  '48,000 kms ',
#  '28,500 kms ',
#  '59,000 kms ',
#  '33,000 kms ',
#  '73,000 kms ',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="Price hover"]')
for i in price_tag:
    price.append(i.text)
len(price)
# Out:
# 840

# %%
price
# Out:
# ['₹ 3.07 Lakh',
#  '₹ 4.10 Lakh',
#  '₹ 27.50 Lakh',
#  '₹ 2.50 Lakh',
#  '₹ 6.35 Lakh',
#  '₹ 29.90 Lakh',
#  '₹ 4.55 Lakh',
#  '₹ 6.10 Lakh',
#  '₹ 8.25 Lakh',
#  '₹ 16 Lakh',
#  '₹ 4.75 Lakh',
#  '₹ 11.85 Lakh',
#  '₹ 6.28 Lakh',
#  '₹ 17 Lakh',
#  '₹ 23 Lakh',
#  '₹ 52.75 Lakh',
#  '₹ 8.65 Lakh',
#  '₹ 61 Lakh',
#  '₹ 37.90 Lakh',
#  '₹ 1.15 Crore',
#  '₹ 7 Lakh',
#  '₹ 2.90 Lakh',
#  '₹ 9.75 Lakh',
#  '₹ 19.90 Lakh',
#  '₹ 1.99 Lakh',
#  '₹ 8.50 Lakh',
#  '₹ 5.90 Lakh',
#  '₹ 72.50 Lakh',
#  '₹ 8.75 Lakh',
#  '₹ 3.75 Lakh',
#  '₹ 11.95 Lakh',
#  '₹ 52.50 Lakh',
#  '₹ 9.25 Lakh',
#  '₹ 9.25 Lakh',
#  '₹ 6.90 Lakh',
#  '₹ 49.90 Lakh',
#  '₹ 18.80 Lakh',
#  '₹ 22.75 Lakh',
#  '₹ 7.60 Lakh',
#  '₹ 21.90 Lakh',
#  '₹ 5.35 Lakh',
#  '₹ 6.35 Lakh',
#  '₹ 9.45 Lakh',
#  '₹ 80 Lakh',
#  '₹ 11 Lakh',
#  '₹ 1.55 Lakh',
#  '₹ 4.75 Lakh',
#  '₹ 33.90 Lakh',
#  '₹ 9.50 Lakh',
#  '₹ 10.75 Lakh',
#  '₹ 6 Lakh',
#  '₹ 34 Lakh',
#  '₹ 3.90 Lakh',
#  '₹ 4.25 Lakh',
#  '₹ 5.85 Lakh',
# ...

# %%
cars_9=pd.DataFrame()
cars_9['Names']=names
cars_9['Types']=types
cars_9['Year of purchase']=year
cars_9['Kms run']=kms
cars_9['Price']=price

cars_9
# Out:
#                                  Names                 Types Year of purchase  \
# 0            Renault Duster Petrol RxL     • Petrol • Manual            2013
# 1    Ford Ecosport 1.5 DV5 MT Titanium     • Diesel • Manual            2014
# 2          Kia Carnival Prestige 6 STR  • Diesel • Automatic            2020
# 3              Maruti Alto 800 CNG LXI        • CNG • Manual            2013
# 4            Honda Amaze S Petrol BSIV     • Petrol • Manual            2019
# ..                                 ...                   ...              ...
# 835  Toyota Innova Crysta 2.7 VX 7 STR     • Petrol • Manual            2020
# 836     Hyundai Creta 1.6 CRDi SX Plus     • Diesel • Manual            2017
# 837    Tata Zest Quadrajet 1.3 75PS XE     • Diesel • Manual            2015
# 838         Toyota Etios Cross 1.4L VD     • Diesel • Manual            2014
# 839           Maruti Wagon R LXI Minor   s • Petrol • Manual            2008
#
#          Kms run         Price
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="cd6353c41983f7dcf887b2107086acc0")>

# %%
driver.maximize_window()

# %%
url='https://www.cars24.com/'
driver.get(url)

# %%
clk=driver.find_element(By.XPATH,'/html/body/div[1]/div[9]/div/div/div/div[2]/div[2]/button')
clk.click()

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag:
    names.append(i.text[4:])
len(names)
# Out:
# 760

# %%
names
# Out:
# [' Hyundai Grand i10',
#  ' Maruti Alto',
#  ' Maruti Swift Dzire',
#  ' Maruti Alto K10',
#  ' Renault TRIBER',
#  ' Hyundai Creta',
#  ' Maruti Dzire',
#  ' Maruti Swift Dzire',
#  ' Renault Duster',
#  ' Skoda Rapid',
#  ' Maruti Wagon R 1.0',
#  ' RENAULT KWID',
#  ' DATSUN REDI GO',
#  ' Maruti Alto 800',
#  ' Maruti SWIFT DZIRE',
#  ' Renault Kwid',
#  ' Maruti VITARA BREZZA',
#  ' HONDA CITY',
#  ' FORD ECOSPORT',
#  ' RENAULT KWID',
#  ' TATA TIAGO',
#  ' Toyota YARIS',
#  ' Maruti Vitara Brezza',
#  ' Renault Kwid',
#  ' Volkswagen Polo',
#  ' Mahindra MARAZZO',
#  ' Hyundai VERNA',
#  ' Hyundai i20',
#  ' Renault Kwid',
#  ' HYUNDAI I20',
#  ' Skoda Rapid',
#  ' Hyundai Creta',
#  ' Hyundai Elite i20',
#  ' Hyundai i20',
#  ' Maruti RITZ',
#  ' HYUNDAI GRAND I10',
#  ' Maruti Baleno',
#  ' Maruti Swift',
#  ' Hyundai Elite i20',
#  ' Volkswagen Ameo',
#  ' Maruti New Wagon-R',
#  ' Ford Ecosport',
#  ' HYUNDAI VERNA',
#  ' Ford Ecosport',
#  ' Hyundai Verna',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag:
    year.append(i.text[0:5])
len(year)
# Out:
# 760

# %%
year
# Out:
# ['2018 ',
#  '2010 ',
#  '2016 ',
#  '2013 ',
#  '2019 ',
#  '2017 ',
#  '2017 ',
#  '2012 ',
#  '2017 ',
#  '2016 ',
#  '2013 ',
#  '2020 ',
#  '2017 ',
#  '2012 ',
#  '2015 ',
#  '2016 ',
#  '2016 ',
#  '2015 ',
#  '2015 ',
#  '2021 ',
#  '2017 ',
#  '2018 ',
#  '2017 ',
#  '2017 ',
#  '2016 ',
#  '2020 ',
#  '2012 ',
#  '2012 ',
#  '2017 ',
#  '2011 ',
#  '2016 ',
#  '2021 ',
#  '2017 ',
#  '2013 ',
#  '2013 ',
#  '2017 ',
#  '2020 ',
#  '2015 ',
#  '2017 ',
#  '2016 ',
#  '2019 ',
#  '2016 ',
#  '2021 ',
#  '2014 ',
#  '2021 ',
#  '2016 ',
#  '2013 ',
#  '2013 ',
#  '2021 ',
#  '2017 ',
#  '2017 ',
#  '2017 ',
#  '2021 ',
#  '2011 ',
#  '2020 ',
#  '2014 ',
#  '2015 ',
#  '2016 ',
#  '2014 ',
#  '2017 ',
#  '2013 ',
#  '2013 ',
#  '2019 ',
#  '2017 ',
#  '2019 ',
#  '2017 ',
#  '2020 ',
#  '2020 ',
#  '2012 ',
#  '2021 ',
#  '2014 ',
#  '2021 ',
#  '2013 ',
#  '2016 ',
#  '2017 ',
#  '2020 ',
#  '2019 ',
#  '2020 ',
#  '2016 ',
#  '2017 ',
#  '2016 ',
#  '2012 ',
#  '2013 ',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag:
    kms.append(i.text[0:9])
len(kms)
# Out:
# 760

# %%
kms
# Out:
# ['42,999 KM',
#  '63,805 KM',
#  '48,294 KM',
#  '43,628 KM',
#  '16,157 KM',
#  '54,913 KM',
#  '31,330 KM',
#  '80,087 KM',
#  '69,037 KM',
#  '89,531 KM',
#  '60,248 KM',
#  '48,540 KM',
#  '30,331 KM',
#  '38,462 KM',
#  '79,214 KM',
#  '61,266 KM',
#  '67,996 KM',
#  '52,340 KM',
#  '61,332 KM',
#  '7,443 KM\n',
#  '29,200 KM',
#  '18,329 KM',
#  '57,510 KM',
#  '26,915 KM',
#  '69,375 KM',
#  '22,707 KM',
#  '48,083 KM',
#  '78,221 KM',
#  '46,397 KM',
#  '91,829 KM',
#  '59,282 KM',
#  '20,205 KM',
#  '49,299 KM',
#  '80,024 KM',
#  '54,860 KM',
#  '70,049 KM',
#  '11,400 KM',
#  '22,873 KM',
#  '38,571 KM',
#  '28,444 KM',
#  '9,723 KM\n',
#  '56,368 KM',
#  '5,473 KM\n',
#  '68,103 KM',
#  '24,255 KM',
#  '19,750 KM',
#  '80,700 KM',
#  '28,999 KM',
#  '5,197 KM\n',
#  '68,362 KM',
#  '63,810 KM',
#  '31,618 KM',
#  '9,747 KM\n',
#  '89,179 KM',
#  '11,932 KM',
#  '61,350 KM',
#  '73,736 KM',
#  '41,023 KM',
#  '90,433 KM',
#  '60,341 KM',
#  '77,938 KM',
#  '75,396 KM',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in type_tag:
    types.append(i.text[18:30])
len(types)
# Out:
# 760

# %%
types
# Out:
# ['R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL',
#  'R\nPETROL',
#  '\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL',
#  'R\nDIESEL',
#  'R\nPETROL',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag:
    price.append(i.text)
len(price)
# Out:
# 760

# %%
cars_10=pd.DataFrame()
cars_10['Names']=names
cars_10['Types']=types
cars_10['Year of purchase']=year
cars_10['Kms run']=kms
cars_10['Price']=price

cars_10
# Out:
#                    Names      Types Year of purchase    Kms run  \
# 0      Hyundai Grand i10  R\nPETROL            2018   42,999 KM
# 1            Maruti Alto  R\nPETROL            2010   63,805 KM
# 2     Maruti Swift Dzire  R\nDIESEL            2016   48,294 KM
# 3        Maruti Alto K10  R\nPETROL            2013   43,628 KM
# 4         Renault TRIBER  R\nPETROL            2019   16,157 KM
# ..                   ...        ...              ...        ...
# 755       RENAULT CAPTUR  R\nDIESEL            2019   49,373 KM
# 756    Hyundai Elite i20  R\nPETROL            2020   18,161 KM
# 757       Maruti CELERIO  R\nPETROL            2016   63,129 KM
# 758         Maruti Swift  R\nPETROL            2018   25,852 KM
# 759         Renault Kwid  R\nPETROL            2018   44,454 KM
#
#                      Price
# 0     ₹5,65,000\n₹5,92,000
# 1                ₹1,80,000
# 2                ₹7,01,000
# 3     ₹2,93,000\n₹3,16,000
# 4     ₹7,23,000\n₹7,41,000
# ..                     ...
# ...

# %%
names1=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag:
    names1.append(i.text[4:])
len(names1)
# Out:
# 560

# %%
names1
# Out:
# [' Skoda Rapid',
#  ' Tata Tiago',
#  ' Renault Kwid',
#  ' Maruti Swift Dzire',
#  ' Tata NEXON',
#  ' Honda Brio',
#  ' Renault Kwid',
#  ' Renault Kwid',
#  ' Volkswagen Polo',
#  ' Maruti Alto K10',
#  ' Hyundai i10',
#  ' Maruti ERTIGA',
#  ' Tata NEXON',
#  ' Honda Amaze',
#  ' RENAULT TRIBER',
#  ' Honda Amaze',
#  ' Honda WR-V',
#  ' Tata NEXON',
#  ' HONDA CITY',
#  ' Hyundai Verna',
#  ' Hyundai i20',
#  ' Skoda Rapid',
#  ' Volkswagen Vento',
#  ' Maruti Celerio',
#  ' Maruti Wagon R 1.0',
#  ' Maruti New Wagon-R',
#  ' Maruti Swift Dzire',
#  ' Maruti Dzire',
#  ' Maruti Wagon R 1.0',
#  ' Maruti Dzire',
#  ' Hyundai Santro Xing',
#  ' Mahindra XUV500',
#  ' Maruti XL6',
#  ' Hyundai NEW SANTRO',
#  ' HYUNDAI GRAND I10',
#  ' Maruti Ciaz',
#  ' Maruti Swift',
#  ' Maruti Vitara Brezza',
#  ' Hyundai i10',
#  ' Maruti SWIFT DZIRE',
#  ' Skoda KUSHAQ',
#  ' Hyundai i20',
#  ' Volkswagen Polo',
#  ' Hyundai GRAND I10 NIOS',
#  ' HYUNDAI NEW SANTRO',
#  ' Volkswagen Polo',
# ...

# %%
year1=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag:
    year1.append(i.text[0:5])
len(year1)
# Out:
# 560

# %%
year1
# Out:
# ['2013 ',
#  '2017 ',
#  '2016 ',
#  '2014 ',
#  '2017 ',
#  '2012 ',
#  '2017 ',
#  '2017 ',
#  '2019 ',
#  '2016 ',
#  '2011 ',
#  '2016 ',
#  '2020 ',
#  '2014 ',
#  '2020 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2015 ',
#  '2017 ',
#  '2011 ',
#  '2016 ',
#  '2015 ',
#  '2018 ',
#  '2017 ',
#  '2020 ',
#  '2014 ',
#  '2017 ',
#  '2015 ',
#  '2018 ',
#  '2013 ',
#  '2018 ',
#  '2019 ',
#  '2019 ',
#  '2013 ',
#  '2016 ',
#  '2018 ',
#  '2016 ',
#  '2014 ',
#  '2012 ',
#  '2022 ',
#  '2011 ',
#  '2013 ',
#  '2021 ',
#  '2020 ',
#  '2015 ',
#  '2018 ',
#  '2017 ',
#  '2016 ',
#  '2018 ',
#  '2018 ',
#  '2021 ',
#  '2015 ',
#  '2020 ',
#  '2013 ',
#  '2020 ',
#  '2011 ',
#  '2017 ',
#  '2019 ',
#  '2015 ',
#  '2017 ',
#  '2012 ',
#  '2019 ',
#  '2014 ',
#  '2021 ',
#  '2021 ',
#  '2020 ',
#  '2015 ',
#  '2021 ',
#  '2012 ',
#  '2016 ',
#  '2012 ',
#  '2019 ',
#  '2015 ',
#  '2018 ',
#  '2018 ',
#  '2014 ',
#  '2017 ',
#  '2018 ',
#  '2014 ',
#  '2014 ',
#  '2018 ',
#  '2021 ',
# ...

# %%
kms1=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag:
    kms1.append(i.text[0:10])
len(kms1)
# Out:
# 560

# %%
kms1
# Out:
# ['71,983 KM\n',
#  '39,909 KM\n',
#  '43,472 KM\n',
#  '24,818 KM\n',
#  '53,596 KM\n',
#  '64,127 KM\n',
#  '14,322 KM\n',
#  '29,152 KM\n',
#  '57,987 KM\n',
#  '16,760 KM\n',
#  '31,653 KM\n',
#  '50,511 KM\n',
#  '31,196 KM\n',
#  '28,969 KM\n',
#  '29,276 KM\n',
#  '36,766 KM\n',
#  '55,664 KM\n',
#  '35,754 KM\n',
#  '36,542 KM\n',
#  '91,613 KM\n',
#  '70,502 KM\n',
#  '59,349 KM\n',
#  '56,238 KM\n',
#  '37,404 KM\n',
#  '60,962 KM\n',
#  '78,496 KM\n',
#  '77,006 KM\n',
#  '32,335 KM\n',
#  '64,616 KM\n',
#  '49,645 KM\n',
#  '90,833 KM\n',
#  '35,238 KM\n',
#  '20,429 KM\n',
#  '17,177 KM\n',
#  '51,978 KM\n',
#  '37,824 KM\n',
#  '67,819 KM\n',
#  '48,477 KM\n',
#  '22,457 KM\n',
#  '37,332 KM\n',
#  '3,569 KM\n1',
#  '87,420 KM\n',
#  '66,597 KM\n',
#  '21,187 KM\n',
#  '6,174 KM\n2',
#  '85,756 KM\n',
#  '16,243 KM\n',
#  '47,772 KM\n',
#  '37,542 KM\n',
#  '28,753 KM\n',
#  '32,339 KM\n',
#  '19,301 KM\n',
#  '83,562 KM\n',
#  '14,081 KM\n',
#  '61,203 KM\n',
# ...

# %%
types1=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in type_tag:
    types1.append(i.text[18:])
len(types1)
# Out:
# 560

# %%
types1
# Out:
# ['R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-47',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-12',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-12',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-04',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nCNG\nMH-03',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nCNG\nMH-12',
#  'R\nDIESEL\nMH-05',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-48',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-04',
#  'R\nDIESEL\nMH-43',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL\nMH-12',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  '\nPETROL\nMH-14',
#  'R\nDIESEL\nMH-12',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-03',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nPETROL',
#  'R\nCNG\nMH-14',
#  'R\nPETROL',
#  'R\nDIESEL\nMH-04',
# ...

# %%
price1=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag:
    price1.append(i.text)
len(price1)
# Out:
# 560

# %%
price1
# Out:
# ['₹4,21,000\n₹4,39,000',
#  '₹5,15,000',
#  '₹3,00,000',
#  '₹5,21,000',
#  '₹7,07,000\n₹7,38,000',
#  '₹3,60,000',
#  '₹3,91,000',
#  '₹3,13,000',
#  '₹6,71,000',
#  '₹3,50,000\n₹3,68,000',
#  '₹2,49,000',
#  '₹7,99,000\n₹8,29,000',
#  '₹10,96,000\n₹11,17,000',
#  '₹4,34,000\n₹4,77,000',
#  '₹6,85,000\n₹7,13,000',
#  '₹7,08,000\n₹7,33,000',
#  '₹7,43,000\n₹7,52,000',
#  '₹10,81,000',
#  '₹7,31,000\n₹7,41,000',
#  '₹8,53,000\n₹8,79,000',
#  '₹3,10,000\n₹3,46,000',
#  '₹6,94,000',
#  '₹5,15,000\n₹5,50,000',
#  '₹4,48,000\n₹4,75,000',
#  '₹4,73,000\n₹4,93,000',
#  '₹5,25,000\n₹5,85,000',
#  '₹4,24,000\n₹4,45,000',
#  '₹5,97,000\n₹6,34,000',
#  '₹3,82,000\n₹4,16,000',
#  '₹7,23,000',
#  '₹2,23,000',
#  '₹13,84,000\n₹15,21,000',
#  '₹10,57,000\n₹11,25,000',
#  '₹5,32,000',
#  '₹4,89,000\n₹5,09,000',
#  '₹7,07,000\n₹7,23,000',
#  '₹6,87,000\n₹6,98,000',
#  '₹7,78,000\n₹7,96,000',
#  '₹3,13,000',
#  '₹3,86,000',
#  '₹15,64,000\n₹16,66,000',
#  '₹3,01,000\n₹3,09,000',
# ...

# %%
cars_11=pd.DataFrame()
cars_11['Names']=names1
cars_11['Types']=types1
cars_11['Year of purchase']=year1
cars_11['Kms run']=kms1
cars_11['Price']=price1

cars_11
# Out:
#                      Names             Types Year of purchase      Kms run  \
# 0              Skoda Rapid         R\nPETROL            2013   71,983 KM\n
# 1               Tata Tiago         R\nPETROL            2017   39,909 KM\n
# 2             Renault Kwid         R\nPETROL            2016   43,472 KM\n
# 3       Maruti Swift Dzire         R\nPETROL            2014   24,818 KM\n
# 4               Tata NEXON         R\nPETROL            2017   53,596 KM\n
# ..                     ...               ...              ...          ...
# 555            Maruti Alto     R\nCNG\nMH-12            2021   36,913 KM\n
# 556   Maruti Vitara Brezza  R\nDIESEL\nMH-03            2018   49,723 KM\n
# 557             Honda Jazz         R\nPETROL            2017   51,245 KM\n
# 558             Honda City         R\nPETROL            2015   73,102 KM\n
# 559          Hyundai VENUE         R\nPETROL            2021   11,124 KM\n
#
#                       Price
# 0      ₹4,21,000\n₹4,39,000
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5af8515d7f4b5f7e2baea37dafd56de5")>

# %%
driver.maximize_window()

# %%
url='https://www.cars24.com/'
driver.get(url)

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in name_tag[0:579]:
    names.append(i.text[4:])
len(names)
# Out:
# 579

# %%
names
# Out:
# [' HYUNDAI GRAND I10',
#  ' Maruti WAGON R 1.0',
#  ' Hyundai i10',
#  ' Honda Amaze',
#  ' HYUNDAI I10',
#  ' Honda Amaze',
#  ' HONDA CITY',
#  ' Honda Amaze',
#  ' Toyota Innova Crysta',
#  ' MAHINDRA XUV500',
#  ' HYUNDAI I10',
#  ' Hyundai i10',
#  ' KIA SONET',
#  ' Maruti Wagon R 1.0',
#  ' MAHINDRA XUV500',
#  ' Maruti DZIRE',
#  ' DATSUN REDI GO',
#  ' Hyundai i10',
#  ' KIA SONET',
#  ' HONDA CITY',
#  ' Maruti ALTO K10',
#  ' Maruti ALTO K10',
#  ' Skoda KUSHAQ',
#  ' Jeep Compass',
#  ' Maruti SWIFT',
#  ' HONDA CITY',
#  ' Maruti Alto',
#  ' KIA SONET',
#  ' Honda City',
#  ' Renault Kwid',
#  ' Hyundai VENUE',
#  ' Hyundai VENUE',
#  ' Jeep Compass',
#  ' KIA CARENS',
#  ' Maruti SWIFT',
#  ' HONDA CITY',
#  ' HONDA CITY',
#  ' Honda Amaze',
#  ' Maruti Ciaz',
#  ' Honda City',
#  ' HYUNDAI I20',
#  ' Renault Kwid',
#  ' Toyota Camry',
#  ' Honda City',
#  ' Maruti Alto 800',
#  ' Hyundai SANTRO XING',
#  ' Honda Amaze',
#  ' Maruti Swift',
#  ' Maruti SWIFT',
# ...

# %%
year=[]
year_tag=driver.find_elements(By.XPATH,'//h2[@class="_2lmIw"]')
for i in year_tag[0:579]:
    year.append(i.text[0:4])
len(year)
# Out:
# 579

# %%
year
# Out:
# ['2020',
#  '2011',
#  '2011',
#  '2015',
#  '2013',
#  '2014',
#  '2022',
#  '2019',
#  '2021',
#  '2019',
#  '2011',
#  '2011',
#  '2020',
#  '2011',
#  '2020',
#  '2017',
#  '2018',
#  '2013',
#  '2021',
#  '2012',
#  '2014',
#  '2014',
#  '2021',
#  '2019',
#  '2011',
#  '2011',
#  '2011',
#  '2020',
#  '2011',
#  '2016',
#  '2021',
#  '2021',
#  '2019',
#  '2022',
#  '2010',
#  '2019',
#  '2013',
#  '2014',
#  '2018',
#  '2021',
#  '2012',
#  '2020',
#  '2015',
#  '2014',
#  '2016',
#  '2014',
#  '2015',
#  '2020',
#  '2011',
#  '2015',
#  '2014',
#  '2021',
#  '2020',
#  '2015',
#  '2016',
#  '2019',
#  '2020',
#  '2018',
#  '2016',
#  '2018',
#  '2011',
#  '2018',
#  '2014',
#  '2021',
#  '2021',
#  '2016',
#  '2016',
#  '2019',
#  '2019',
#  '2014',
#  '2021',
#  '2019',
#  '2018',
#  '2015',
#  '2021',
#  '2015',
#  '2015',
#  '2012',
#  '2015',
#  '2015',
#  '2020',
#  '2015',
#  '2021',
#  '2014',
#  '2018',
#  '2020',
#  '2016',
#  '2017',
#  '2014',
#  '2020',
# ...

# %%
kms=[]
km_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in km_tag[0:579]:
    kms.append(i.text[0:11])
len(kms)
# Out:
# 579

# %%
kms
# Out:
# ['13,851 KM\n2',
#  '33,528 KM\n1',
#  '32,932 KM\n1',
#  '31,420 KM\n1',
#  '41,378 KM\n2',
#  '77,120 KM\n1',
#  '2,424 KM\n1S',
#  '15,119 KM\n1',
#  '6,205 KM\n1S',
#  '57,814 KM\n1',
#  '18,495 KM\n2',
#  '32,648 KM\n1',
#  '12,835 KM\n1',
#  '28,979 KM\n1',
#  '49,231 KM\n1',
#  '14,796 KM\n1',
#  '16,549 KM\n1',
#  '66,064 KM\n1',
#  '6,978 KM\n1S',
#  '38,501 KM\n1',
#  '21,683 KM\n1',
#  '21,670 KM\n1',
#  '7,182 KM\n1S',
#  '47,136 KM\n1',
#  '73,738 KM\n2',
#  '62,075 KM\n2',
#  '12,174 KM\n2',
#  '12,461 KM\n1',
#  '30,674 KM\n1',
#  '48,834 KM\n2',
#  '6,063 KM\n1S',
#  '14,123 KM\n1',
#  '23,690 KM\n1',
#  '3,084 KM\n1S',
#  '21,660 KM\n1',
#  '99,460 KM\n1',
#  '32,933 KM\n1',
#  '55,379 KM\n1',
#  '60,583 KM\n1',
#  '9,326 KM\n1S',
#  '70,108 KM\n1',
#  '13,095 KM\n1',
#  '93,626 KM\n1',
#  '59,456 KM\n1',
#  '61,606 KM\n1',
#  '43,944 KM\n1',
#  '28,632 KM\n1',
#  '26,424 KM\n1',
#  '80,296 KM\n2',
#  '48,532 KM\n3',
#  '27,324 KM\n1',
#  '9,913 KM\n1S',
# ...

# %%
types=[]
type_tag=driver.find_elements(By.XPATH,'//ul[@class="_13yb6"]')
for i in type_tag[0:579]:
    types.append(i.text[19:])
len(types)
# Out:
# 579

# %%
types
# Out:
# ['\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-14',
#  '\nPETROL',
#  'DIESEL\nUP-14',
#  '\nDIESEL\nDL-8C',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nDIESEL\nHR-26',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nHR-26',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-8C',
#  '\nDIESEL\nHR-26',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nUP-85',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nUP-11',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nHR-51',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  'PETROL\nDL-3C',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
#  '\nPETROL',
# ...

# %%
area=[]
area_tag=driver.find_elements(By.XPATH,'//span[@class="_3DYbK"]')
for i in area_tag:
    area.append(i.text)
len(area)
# Out:
# 579

# %%
area
# Out:
# ['Metro Walk, Rohini, New Delhi',
#  'Ansal API, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Sector-18, Noida',
#  'Ansal API, Gurgaon',
#  'GIP Mall, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'Spaze Platinum, Gurgaon',
#  'Sector-18, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'GIP Mall, Noida',
#  'Ansal API, Gurgaon',
#  'Spaze Platinum, Gurgaon',
#  'Sector-18, Noida',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Sector-18, Noida',
#  'Metro Walk, Rohini, New Delhi',
#  'Ansal API, Gurgaon',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Spaze Platinum, Gurgaon',
#  'Metro Walk, Rohini, New Delhi',
#  'Ansal API, Gurgaon',
#  'Parsvnath City Mall, Faridabad',
#  'Sector-18, Noida',
#  'GIP Mall, Noida',
#  'Ansal API, Gurgaon',
#  'GIP Mall, Noida',
#  'Sector-18, Noida',
#  'Vasant Square Mall, New Delhi',
#  'Metro Walk, Rohini, New Delhi',
#  'Spaze Platinum, Gurgaon',
# ...

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="_18ToE"]')
for i in price_tag[0:579]:
    price.append(i.text)
len(price)
# Out:
# 579

# %%
cars_12=pd.DataFrame()
cars_12['Names']=names
cars_12['Types']=types
cars_12['Year of purchase']=year
cars_12['Kms run']=kms
cars_12['Price']=price
cars_12['Area']=area

cars_12
# Out:
#                    Names            Types Year of purchase       Kms run  \
# 0      HYUNDAI GRAND I10         \nPETROL             2020  13,851 KM\n2
# 1     Maruti WAGON R 1.0         \nPETROL             2011  33,528 KM\n1
# 2            Hyundai i10         \nPETROL             2011  32,932 KM\n1
# 3            Honda Amaze         \nPETROL             2015  31,420 KM\n1
# 4            HYUNDAI I10         \nPETROL             2013  41,378 KM\n2
# ..                   ...              ...              ...           ...
# 574        Mahindra Thar  \nDIESEL\nHR-51             2021  17,262 KM\n1
# 575        Maruti Baleno         \nPETROL             2018  12,905 KM\n1
# 576         Maruti Swift         \nPETROL             2019  38,123 KM\n1
# 577   Hyundai NEW SANTRO     \nCNG\nDL-7C             2021  53,039 KM\n1
# 578        Maruti Baleno         \nPETROL             2019  29,414 KM\n2
#
#                     Price                           Area
# ...

# %%
import pandas as pd

# %%
lst=[cars,cars_1,cars_2,cars_3,cars_4,cars_5,cars_6,cars_7,cars_8,cars_9,cars_10,cars_11,cars_12]

# %%
df=pd.concat(lst)

# %%
df.head()
# Out:
#             Names                       Area Year of purchase      Kms run  \
# 0   Hyundai Venue       Indira Nagar\nJan 22             2020    17,206 km
# 1     Hyundai i20       Kedari Nagar\nJan 21             2013    30,000 km
# 2     Skoda Rapid  Banjara Hills\n4 days ago             2013    92,000 km
# 3  Chevrolet Beat       Dhanurjayapur\nToday             2016   180,000 km
# 4    Renault KWID     Banganga Colony\nToday             2018    30,000 km
#
#          Price Types
# 0  ₹ 10,65,000   NaN
# 1   ₹ 3,75,000   NaN
# 2   ₹ 3,80,000   NaN
# 3   ₹ 1,70,000   NaN
# 4   ₹ 2,50,000   NaN

# %%
df.shape
# Out:
# (5127, 6)

# %%
df.isnull().sum()
# Out:
# Names                  0
# Area                2240
# Year of purchase       0
# Kms run                0
# Price                  0
# Types                 40
# dtype: int64

# %%
df.dtypes
# Out:
# Names               object
# Area                object
# Year of purchase    object
# Kms run             object
# Price               object
# Types               object
# dtype: object

# %%
# lets treat the nulls
df['Area']=df['Area'].fillna(df['Area'].mode()[0])

# %%
df['Types']=df['Types'].fillna(df['Types'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Names               0
# Area                0
# Year of purchase    0
# Kms run             0
# Price               0
# Types               0
# dtype: int64

# %%
# lets encode the columns as computer only understands numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Names'])
df['Names']=df2

# %%
lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Area'])
df['Area']=df2

# %%
lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Year of purchase'])
df['Year of purchase']=df2

# %%
lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Kms run'])
df['Kms run']=df2

# %%
lab_enc=LabelEncoder()
df2=lab_enc.fit_transform(df['Types'])
df['Types']=df2

# %%
df.dtypes
# Out:
# Names                int32
# Area                 int32
# Year of purchase     int32
# Kms run              int32
# Price               object
# Types                int32
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
df.head()
# Out:
#    Names  Area  Year of purchase  Kms run  Price  Types
# 0   1189   112                32      170   60.0     60
# 1   1223   152                18      177  228.0     60
# 2   1548    51                18      192  229.0     60
# 3    869    73                24      171   13.0     60
# 4   1523    50                28      177  140.0     60

# %%
df.describe()
# Out:
#              Names         Area  Year of purchase      Kms run        Price  \
# count  5127.000000  5127.000000       5127.000000  5127.000000  5127.000000
# mean    512.681295   174.910669         26.440999  2291.039204  1382.873415
# std     460.831151    70.724448          6.261001  1370.860806   860.247197
# min       0.000000     0.000000          0.000000     0.000000     0.000000
# 25%     150.000000   180.000000         23.000000  1100.500000   583.500000
# 50%     335.000000   180.000000         27.000000  2299.000000  1399.000000
# 75%     770.000000   180.000000         31.000000  3483.500000  2109.500000
# max    1670.000000   304.000000         43.000000  4665.000000  2925.000000
#
#              Types
# count  5127.000000
# mean    234.234445
# std     171.732875
# min       0.000000
# 25%      60.000000
# 50%     278.000000
# 75%     388.000000
# max     446.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
    plotnumber+=1
plt.show()

# %%
# check the skewness
df.skew()
# Out:
# Names               0.985916
# Area               -0.384699
# Year of purchase   -0.628417
# Kms run             0.004413
# Price               0.048543
# Types              -0.001502
# dtype: float64

# %%
df.head()
# Out:
#    Names  Area  Year of purchase  Kms run  Price  Types
# 0   1189   112                32      170   60.0     60
# 1   1223   152                18      177  228.0     60
# 2   1548    51                18      192  229.0     60
# 3    869    73                24      171   13.0     60
# 4   1523    50                28      177  140.0     60

# %%
#lets split the dataset into features and label

# %%
x=df.drop(columns=['Price'])
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(x_test)
y_pred
# Out:
# array([1575., 1820., 2202., ..., 1392.,  215., 2366.])

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.0046801872074883

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("\n ====== train result============")
        print(f"accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%")
    elif train==False:
        pred=clf.predict(x_test)
        print("========test result===============")
        print(f"accuracy score:{accuracy_score(y_test,pred)*100:.2f}%")

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
metric_score(knn,x_train,x_test,y_train,y_test,train=True)
metric_score(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
#  ====== train result============
# accuracy score:20.57%
# ========test result===============
# accuracy score:0.16%

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state{i},the training accuracy is{r2_score(y_train,pred_train)}")
    print(f"at random state{i},the training accuracy is{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# at random state0,the training accuracy is0.451936924582376
# at random state0,the training accuracy is0.44421935479260444
#
#
# at random state1,the training accuracy is0.45176281085108005
# at random state1,the training accuracy is0.4442506854664532
#
#
# at random state2,the training accuracy is0.45045176690188016
# at random state2,the training accuracy is0.4484810987223964
#
#
# at random state3,the training accuracy is0.4457255233200872
# at random state3,the training accuracy is0.46396338710610074
#
#
# at random state4,the training accuracy is0.44822854356219066
# at random state4,the training accuracy is0.45594131172322205
#
#
# at random state5,the training accuracy is0.451426053588991
# at random state5,the training accuracy is0.4461433534948568
#
#
# at random state6,the training accuracy is0.44714782030177924
# at random state6,the training accuracy is0.45879490014957336
#
#
# at random state7,the training accuracy is0.45556114164983963
# ...

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 44.59183421074133

# %%
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.4635968962969609

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],
           'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('r2_score',rfs)
# Out:
# r2_score 0.7019286970573579

# %%
# saving the model
import pickle

# %%
pickle.dump(rf,open('car_prediction','wb'))

# %%
loaded_model=pickle.load(open('car_prediction','rb'))

# %%
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 70.19286970573579

# %%
#=============thank you==================
